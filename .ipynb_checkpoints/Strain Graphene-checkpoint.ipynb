# %% [markdown]
# # Strain Graphene
#
# Theses examples illustrate the impact of triaxial linear strain on graphene flakes:
# - Formations Pseudo Landau levels (pLLs).
# - Energies depending on strain strength.
# - Flake geometry influence.
# - Vacancy defect induced states between pLLs.
# - Negative couplings induced states between pLLs.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from graphene_tb import *
# %matplotlib inline

# %%
graphene_tb = grapheneTB()
t1, t2, t3 = 1., 1., 1.

# %% [markdown]
# ## Squared flake

# %%
graphene_tb.get_lattice(flake=square, n=10)
plt_graphene = plotGraphene(graphene_tb.coor, graphene_tb.tags)
eig_graphene = eigGraphene(graphene_tb.coor, graphene_tb.coor_rec, graphene_tb.tags)

# %%
fig_lat = plt_graphene.plt_lattice(graphene_tb.coor, ms=8)

# %%
eig_graphene.get_beta_lims()
print('strain limits', eig_graphene.beta_lims)
# Out:
# strain limits [-0.11  0.11]

# %%
eig_graphene.get_hops(t1, t2, t3, beta=eig_graphene.beta_lims[1], get_hop_rec=True)

# %%
eig_graphene.get_coor_hop(graphene_tb.nx, graphene_tb.ny,
           graphene_tb.coor_rec, graphene_tb.ind)
fig_lat_hop = plt_graphene.plt_lattice(eig_graphene.coor_hop, ms=8)

# %%
# eigenvalue problem
eig_graphene.get_ham()
eig_graphene.get_eigh()
fig_spec = plt_graphene.plt_spec(en=eig_graphene.en, en_lims=[-1.5, 1.5], 
                                 pola=eig_graphene.pola, pola_tag=b'a')

# %%
# butterfly
eig_graphene.get_butterfly(t1, t2, t3, N=10)
fig_butterfly = plt_graphene.plt_butterfly(eig_graphene.butterfly, eig_graphene.betas, 
                                           en_lims=[-2., 2.])

# %% [markdown]
# ## Circular flake

# %%
graphene_tb.get_lattice(flake=circle, n=10)
plt_graphene = plotGraphene(graphene_tb.coor, graphene_tb.tags)
eig_graphene = eigGraphene(graphene_tb.coor, graphene_tb.coor_rec, graphene_tb.tags)

fig_lat = plt_graphene.plt_lattice(graphene_tb.coor, ms=8)

eig_graphene.get_beta_lims()
print('strain limits', eig_graphene.beta_lims)

eig_graphene.get_hops(t1, t2, t3, beta=eig_graphene.beta_lims[1], get_hop_rec=True)

eig_graphene.get_coor_hop(graphene_tb.nx, graphene_tb.ny,
           graphene_tb.coor_rec, graphene_tb.ind)
fig_lat_hop = plt_graphene.plt_lattice(eig_graphene.coor_hop, ms=8)
# Out:
# strain limits [-0.11  0.11]

# %%
# eigenvalue problem
eig_graphene.get_ham()
eig_graphene.get_eigh()
fig_spec = plt_graphene.plt_spec(en=eig_graphene.en, en_lims=[-1.5, 1.5], 
                                 pola=eig_graphene.pola, pola_tag=b'a')

# %%
# butterfly
eig_graphene.get_butterfly(t1, t2, t3, N=10)
fig_butterfly = plt_graphene.plt_butterfly(eig_graphene.butterfly, eig_graphene.betas, 
                                           en_lims=[-2., 2.])

# %% [markdown]
# ## Hexagonal flake - Armchair terminations

# %%
graphene_tb.get_lattice(flake=hex_ac, n=10)
plt_graphene = plotGraphene(graphene_tb.coor, graphene_tb.tags)
eig_graphene = eigGraphene(graphene_tb.coor, graphene_tb.coor_rec, graphene_tb.tags)

fig_lat = plt_graphene.plt_lattice(graphene_tb.coor, ms=8)

eig_graphene.get_beta_lims()

eig_graphene.get_hops(t1, t2, t3, beta=eig_graphene.beta_lims[1], get_hop_rec=True)

eig_graphene.get_coor_hop(graphene_tb.nx, graphene_tb.ny,
           graphene_tb.coor_rec, graphene_tb.ind)
fig_lat_hop = plt_graphene.plt_lattice(eig_graphene.coor_hop, ms=8)

# %%
# eigenvalue problem
eig_graphene.get_ham()
eig_graphene.get_eigh()
fig_spec = plt_graphene.plt_spec(en=eig_graphene.en, en_lims=[-1.5, 1.5], 
                                 pola=eig_graphene.pola, pola_tag=b'a')

# %%
# butterfly
eig_graphene.get_butterfly(t1, t2, t3, N=10)
fig_butterfly = plt_graphene.plt_butterfly(eig_graphene.butterfly, eig_graphene.betas, 
                                           en_lims=[-1.5, 1.5])

# %% [markdown]
# ## Triangular flake - Armchain terminations

# %%
graphene_tb.get_lattice(flake=tri_ac, n=20)
plt_graphene = plotGraphene(graphene_tb.coor, graphene_tb.tags)
eig_graphene = eigGraphene(graphene_tb.coor, graphene_tb.coor_rec, graphene_tb.tags)

fig_lat = plt_graphene.plt_lattice(graphene_tb.coor, ms=8)

eig_graphene.get_beta_lims()
print('strain limits', eig_graphene.beta_lims)
eig_graphene.get_hops(t1, t2, t3, beta=eig_graphene.beta_lims[1], get_hop_rec=True)

eig_graphene.get_coor_hop(graphene_tb.nx, graphene_tb.ny,
           graphene_tb.coor_rec, graphene_tb.ind)
fig_lat_hop = plt_graphene.plt_lattice(eig_graphene.coor_hop, ms=8)
# Out:
# beta limits [-0.11  0.11]

# %%
# eigenvalue problem
eig_graphene.get_ham()
eig_graphene.get_eigh()
fig_spec = plt_graphene.plt_spec(en=eig_graphene.en, en_lims=[-1.5, 1.5], 
                                 pola=eig_graphene.pola, pola_tag=b'a')

# %%
# butterfly
eig_graphene.get_butterfly(t1, t2, t3, N=10)
fig_butterfly = plt_graphene.plt_butterfly(eig_graphene.butterfly, eig_graphene.betas, 
                                           en_lims=[-1.5, 1.5])

# %% [markdown]
# ## Hexagonal flake - Zigzag  terminations

# %%
graphene_tb.get_lattice(flake=hex_zz, n=10)
plt_graphene = plotGraphene(graphene_tb.coor, graphene_tb.tags)
eig_graphene = eigGraphene(graphene_tb.coor, graphene_tb.coor_rec, graphene_tb.tags)

fig_lat = plt_graphene.plt_lattice(graphene_tb.coor, ms=8)

eig_graphene.get_beta_lims()
print('strain limits', eig_graphene.beta_lims)

eig_graphene.get_hops(t1, t2, t3, beta=eig_graphene.beta_lims[1], get_hop_rec=True)

eig_graphene.get_coor_hop(graphene_tb.nx, graphene_tb.ny,
           graphene_tb.coor_rec, graphene_tb.ind)
fig_lat_hop = plt_graphene.plt_lattice(eig_graphene.coor_hop, ms=8)
# Out:
# strain limits [-0.14  0.14]

# %%
# eigenvalue problem
eig_graphene.get_ham()
eig_graphene.get_eigh()
fig_spec = plt_graphene.plt_spec(en=eig_graphene.en, en_lims=[-1.5, 1.5], 
                                 pola=eig_graphene.pola, pola_tag=b'a')

# %%
# butterfly
eig_graphene.get_butterfly(t1, t2, t3, N=10)
fig_butterfly = plt_graphene.plt_butterfly(eig_graphene.butterfly, eig_graphene.betas, 
                                           en_lims=[-2., 2.])

# %% [markdown]
# ## Triangular flake - Zigzag terminations

# %%
graphene_tb.get_lattice(flake=tri_zz, n=20)
plt_graphene = plotGraphene(graphene_tb.coor, graphene_tb.tags)
eig_graphene = eigGraphene(graphene_tb.coor, graphene_tb.coor_rec, graphene_tb.tags)

fig_lat = plt_graphene.plt_lattice(graphene_tb.coor, ms=8)

eig_graphene.get_beta_lims()
print('strain limits', eig_graphene.beta_lims)

eig_graphene.get_hops(t1, t2, t3, beta=eig_graphene.beta_lims[1], get_hop_rec=True)

eig_graphene.get_coor_hop(graphene_tb.nx, graphene_tb.ny,
           graphene_tb.coor_rec, graphene_tb.ind)
fig_lat_hop = plt_graphene.plt_lattice(eig_graphene.coor_hop, ms=8)

# %%
# eigenvalue problem
eig_graphene.get_ham()
eig_graphene.get_eigh()
fig_spec = plt_graphene.plt_spec(en=eig_graphene.en, en_lims=[-2.5, 2.5], 
                                 pola=eig_graphene.pola, pola_tag=b'a')

# %%
# butterfly
eig_graphene.get_butterfly(t1, t2, t3, N=10)
fig_butterfly = plt_graphene.plt_butterfly(eig_graphene.butterfly, eig_graphene.betas, 
                                           en_lims=[-2.5, 2.5])
