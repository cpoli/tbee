# %% [markdown]
# # GRAPHENE FLAKES

# %%
from grapheneTB import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Quick examples

# %% [markdown]
# ### lattice with nearest and next-nearest hoppings

# %%
lat = grapheneTB()
sys = eigTB(lat=lat)
plot = plotTB(sys=sys)
lat.get_lattice(n1=6, n2=6)
plot.lattice(ms=8);

# %%
sys = grapheneEig(lat)
plot = plotTB(sys)
sys.print_hop(n=2)
# Out:
# 54 different distances between nodes:
#
# Distances between sites:
# 1st hopping, length: 1.000
# 	with positive angles:
# 	 [ 30.0  90.0  150.0]
# 2nd hopping, length: 1.732
# 	with positive angles:
# 	 [ 0.0  60.0  120.0  180.0]

# %%
sys.set_hopping([{'n':1, 't':1.}, {'n':2, 't':.1}])

# %%
print(sys.hop)
# Out:
# [(1, 0, 6, (1+0j), 30, b'ab') (1, 1, 6, (1+0j), 150, b'bb')
#  (1, 1, 7, (1+0j), 30, b'ba') (1, 2, 7, (1+0j), 150, b'aa')
#  (1, 2, 8, (1+0j), 30, b'ab') (1, 3, 8, (1+0j), 150, b'ab')
#  (1, 3, 9, (1+0j), 30, b'aa') (1, 4, 9, (1+0j), 150, b'ba')
#  (1, 4, 10, (1+0j), 30, b'ba') (1, 5, 10, (1+0j), 150, b'aa')
#  (1, 5, 11, (1+0j), 30, b'ab') (1, 6, 12, (1+0j), 90, b'ba')
#  (1, 7, 13, (1+0j), 90, b'ab') (1, 8, 14, (1+0j), 90, b'ba')
#  (1, 9, 15, (1+0j), 90, b'ab') (1, 10, 16, (1+0j), 90, b'aa')
#  (1, 11, 17, (1+0j), 90, b'bb') (1, 12, 18, (1+0j), 30, b'aa')
#  (1, 13, 18, (1+0j), 150, b'ba') (1, 13, 19, (1+0j), 30, b'bb')
#  (1, 14, 19, (1+0j), 150, b'ab') (1, 14, 20, (1+0j), 30, b'aa')
#  (1, 15, 20, (1+0j), 150, b'ba') (1, 15, 21, (1+0j), 30, b'ba')
#  (1, 16, 21, (1+0j), 150, b'aa') (1, 16, 22, (1+0j), 30, b'ab')
#  (1, 17, 22, (1+0j), 150, b'bb') (1, 17, 23, (1+0j), 30, b'ba')
#  (1, 18, 24, (1+0j), 90, b'ab') (1, 19, 25, (1+0j), 90, b'ba')
#  (1, 20, 26, (1+0j), 90, b'ab') (1, 21, 27, (1+0j), 90, b'ab')
#  (1, 22, 28, (1+0j), 90, b'ba') (1, 23, 29, (1+0j), 90, b'ab')
#  (1, 24, 30, (1+0j), 30, b'ba') (1, 25, 30, (1+0j), 150, b'aa')
#  (1, 25, 31, (1+0j), 30, b'ab') (1, 26, 31, (1+0j), 150, b'bb')
#  (1, 26, 32, (1+0j), 30, b'ba') (1, 27, 32, (1+0j), 150, b'ba')
#  (1, 27, 33, (1+0j), 30, b'ba') (1, 28, 33, (1+0j), 150, b'aa')
#  (1, 28, 34, (1+0j), 30, b'ab') (1, 29, 34, (1+0j), 150, b'bb')
#  (1, 29, 35, (1+0j), 30, b'ba') (1, 30, 36, (1+0j), 90, b'ab')
#  (1, 31, 37, (1+0j), 90, b'ba') (1, 32, 38, (1+0j), 90, b'ab')
#  (2, 5, 16, (0.1+0j), 120, b'aa') (2, 5, 17, (0.1+0j), 60, b'ab')
#  (2, 6, 7, (0.1+0j), 0, b'ba') (2, 6, 18, (0.1+0j), 60, b'ba')
#  (2, 7, 8, (0.1+0j), 0, b'ab') (2, 7, 18, (0.1+0j), 120, b'aa')
#  (2, 7, 19, (0.1+0j), 60, b'ab') (2, 8, 9, (0.1+0j), 0, b'ba')
#  (2, 8, 19, (0.1+0j), 120, b'bb') (2, 8, 20, (0.1+0j), 60, b'ba')
#  (2, 9, 10, (0.1+0j), 0, b'aa') (2, 9, 20, (0.1+0j), 120, b'aa')
#  (2, 9, 21, (0.1+0j), 60, b'aa') (2, 10, 11, (0.1+0j), 0, b'ab')
#  (2, 10, 21, (0.1+0j), 120, b'aa') (2, 10, 22, (0.1+0j), 60, b'ab')
#  (2, 11, 22, (0.1+0j), 120, b'bb') (2, 11, 23, (0.1+0j), 60, b'ba')
#  (2, 12, 13, (0.1+0j), 0, b'ab') (2, 12, 24, (0.1+0j), 60, b'ab')
#  (2, 13, 14, (0.1+0j), 0, b'ba') (2, 13, 24, (0.1+0j), 120, b'bb')
#  (2, 13, 25, (0.1+0j), 60, b'ba') (2, 14, 15, (0.1+0j), 0, b'ab')
#  (2, 14, 25, (0.1+0j), 120, b'aa') (2, 14, 26, (0.1+0j), 60, b'ab')
#  (2, 15, 16, (0.1+0j), 0, b'ba') (2, 15, 26, (0.1+0j), 120, b'bb')
#  (2, 15, 27, (0.1+0j), 60, b'bb') (2, 16, 17, (0.1+0j), 0, b'ab')
#  (2, 16, 27, (0.1+0j), 120, b'ab') (2, 16, 28, (0.1+0j), 60, b'aa')
#  (2, 17, 28, (0.1+0j), 120, b'ba') (2, 17, 29, (0.1+0j), 60, b'bb')
#  (2, 18, 19, (0.1+0j), 0, b'ab') (2, 18, 30, (0.1+0j), 60, b'aa')
#  (2, 19, 20, (0.1+0j), 0, b'ba') (2, 19, 30, (0.1+0j), 120, b'ba')
#  (2, 19, 31, (0.1+0j), 60, b'bb') (2, 20, 21, (0.1+0j), 0, b'aa')
#  (2, 20, 31, (0.1+0j), 120, b'ab') (2, 20, 32, (0.1+0j), 60, b'aa')
#  (2, 21, 22, (0.1+0j), 0, b'ab') (2, 21, 32, (0.1+0j), 120, b'aa')
#  (2, 21, 33, (0.1+0j), 60, b'aa') (2, 22, 23, (0.1+0j), 0, b'ba')
#  (2, 22, 33, (0.1+0j), 120, b'ba') (2, 22, 34, (0.1+0j), 60, b'bb')
#  (2, 23, 34, (0.1+0j), 120, b'ab') (2, 23, 35, (0.1+0j), 60, b'aa')
#  (2, 24, 25, (0.1+0j), 0, b'ba') (2, 24, 36, (0.1+0j), 60, b'bb')
#  (2, 25, 26, (0.1+0j), 0, b'ab') (2, 25, 36, (0.1+0j), 120, b'ab')
#  (2, 25, 37, (0.1+0j), 60, b'aa') (2, 26, 27, (0.1+0j), 0, b'bb')
#  (2, 26, 37, (0.1+0j), 120, b'ba') (2, 26, 38, (0.1+0j), 60, b'bb')
#  (2, 27, 28, (0.1+0j), 0, b'ba') (2, 27, 38, (0.1+0j), 120, b'bb')
#  (2, 27, 39, (0.1+0j), 60, b'bb') (2, 28, 29, (0.1+0j), 0, b'ab')
#  (2, 28, 39, (0.1+0j), 120, b'ab') (2, 28, 40, (0.1+0j), 60, b'aa')
#  (2, 29, 40, (0.1+0j), 120, b'ba') (2, 29, 41, (0.1+0j), 60, b'bb')
#  (2, 30, 31, (0.1+0j), 0, b'ab') (2, 30, 42, (0.1+0j), 60, b'aa')
#  (2, 31, 32, (0.1+0j), 0, b'ba') (2, 31, 42, (0.1+0j), 120, b'ba')
#  (2, 31, 43, (0.1+0j), 60, b'bb') (2, 32, 33, (0.1+0j), 0, b'aa')
#  (2, 32, 43, (0.1+0j), 120, b'ab') (2, 32, 44, (0.1+0j), 60, b'aa')
#  (2, 33, 34, (0.1+0j), 0, b'ab') (2, 33, 44, (0.1+0j), 120, b'aa')
#  (2, 33, 45, (0.1+0j), 60, b'aa') (2, 34, 35, (0.1+0j), 0, b'ba')
#  (2, 34, 45, (0.1+0j), 120, b'ba') (2, 34, 46, (0.1+0j), 60, b'bb')
#  (2, 35, 46, (0.1+0j), 120, b'ab') (2, 35, 47, (0.1+0j), 60, b'aa')
#  (2, 36, 37, (0.1+0j), 0, b'ba') (2, 36, 48, (0.1+0j), 60, b'bb')
#  (2, 37, 38, (0.1+0j), 0, b'ab') (2, 37, 48, (0.1+0j), 120, b'ab')
#  (2, 37, 49, (0.1+0j), 60, b'aa') (2, 38, 39, (0.1+0j), 0, b'bb')
#  (2, 38, 49, (0.1+0j), 120, b'ba') (2, 38, 50, (0.1+0j), 60, b'bb')
#  (2, 39, 40, (0.1+0j), 0, b'ba') (2, 39, 50, (0.1+0j), 120, b'bb')
#  (2, 39, 51, (0.1+0j), 60, b'bb') (2, 40, 41, (0.1+0j), 0, b'ab')
#  (2, 40, 51, (0.1+0j), 120, b'ab') (2, 40, 52, (0.1+0j), 60, b'aa')
#  (2, 41, 52, (0.1+0j), 120, b'ba') (2, 41, 53, (0.1+0j), 60, b'bb')
#  (2, 42, 43, (0.1+0j), 0, b'ab') (2, 42, 54, (0.1+0j), 60, b'aa')
#  (2, 43, 44, (0.1+0j), 0, b'ba') (2, 43, 54, (0.1+0j), 120, b'ba')
#  (2, 43, 55, (0.1+0j), 60, b'bb') (2, 44, 45, (0.1+0j), 0, b'aa')
#  (2, 44, 55, (0.1+0j), 120, b'ab') (2, 44, 56, (0.1+0j), 60, b'aa')
#  (2, 45, 46, (0.1+0j), 0, b'ab') (2, 45, 56, (0.1+0j), 120, b'aa')
#  (2, 45, 57, (0.1+0j), 60, b'ab') (2, 46, 47, (0.1+0j), 0, b'ba')
#  (2, 46, 57, (0.1+0j), 120, b'bb') (2, 46, 58, (0.1+0j), 60, b'ba')
#  (2, 47, 58, (0.1+0j), 120, b'aa') (2, 47, 59, (0.1+0j), 60, b'ab')
#  (2, 48, 49, (0.1+0j), 0, b'ba') (2, 48, 60, (0.1+0j), 60, b'ba')
#  (2, 49, 50, (0.1+0j), 0, b'ab') (2, 49, 60, (0.1+0j), 120, b'aa')
#  (2, 49, 61, (0.1+0j), 60, b'ab') (2, 50, 51, (0.1+0j), 0, b'bb')
#  (2, 50, 61, (0.1+0j), 120, b'bb') (2, 50, 62, (0.1+0j), 60, b'bb')
#  (2, 51, 52, (0.1+0j), 0, b'ba') (2, 51, 62, (0.1+0j), 120, b'bb')
#  (2, 51, 63, (0.1+0j), 60, b'ba') (2, 52, 53, (0.1+0j), 0, b'ab')
#  (2, 52, 63, (0.1+0j), 120, b'aa') (2, 52, 64, (0.1+0j), 60, b'ab')
#  (2, 53, 64, (0.1+0j), 120, b'bb') (2, 53, 65, (0.1+0j), 60, b'ba')
#  (2, 54, 55, (0.1+0j), 0, b'ab') (2, 54, 66, (0.1+0j), 60, b'ab')
#  (2, 55, 56, (0.1+0j), 0, b'ba') (2, 55, 66, (0.1+0j), 120, b'bb')
#  (2, 55, 67, (0.1+0j), 60, b'ba') (2, 56, 57, (0.1+0j), 0, b'ab')
#  (2, 56, 67, (0.1+0j), 120, b'aa') (2, 56, 68, (0.1+0j), 60, b'ab')
#  (2, 57, 58, (0.1+0j), 0, b'ba') (2, 57, 68, (0.1+0j), 120, b'bb')
#  (2, 57, 69, (0.1+0j), 60, b'bb') (2, 58, 59, (0.1+0j), 0, b'ab')
#  (2, 58, 69, (0.1+0j), 120, b'ab') (2, 58, 70, (0.1+0j), 60, b'aa')
#  (2, 59, 70, (0.1+0j), 120, b'ba') (2, 59, 71, (0.1+0j), 60, b'bb')
#  (2, 60, 61, (0.1+0j), 0, b'ab') (2, 61, 62, (0.1+0j), 0, b'bb')
#  (2, 62, 63, (0.1+0j), 0, b'ba') (2, 63, 64, (0.1+0j), 0, b'ab')
#  (2, 64, 65, (0.1+0j), 0, b'ba') (2, 66, 67, (0.1+0j), 0, b'ba')
#  (2, 67, 68, (0.1+0j), 0, b'ab') (2, 68, 69, (0.1+0j), 0, b'bb')
#  (2, 69, 70, (0.1+0j), 0, b'ba') (2, 70, 71, (0.1+0j), 0, b'ab')]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig()

# %%
plot.spectrum();
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### lattice with different hopping values

# %%
lat = grapheneTB()
sys = eigTB(lat=lat)
plot = plotTB(sys=sys)
lat.get_lattice(n1=6, n2=6)
plot.lattice(ms=8);

# %%
sys.set_hopping([{'n': 1,'tag':b'ba', 't':1}, 
                 {'n': 1,'tag':b'ab', 't':2},
                 {'n': 1,'tag':b'ba', 't':3}])
'''
sys.rename_hop_tag([{'n':1, 'ang':90, 'tag': b'ba', 'tag_new': b'u'}, 
                    {'n':1,'ang':30, 'tag': b'ab', 'tag_new': b'v'}, 
                    {'n':1,'ang':150, 'tag': b'ba', 'tag_new': b'w'}])
'''
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-1e62cf9e1dd0> in <module>()
#       1 sys.set_hopping([{'n': 1,'tag':b'ba', 't':1},
#       2                  {'n': 1,'tag':b'ab', 't':2},
# ----> 3                  {'n': 1,'tag':b'ba', 't':3}])
#       4 '''
#       5 sys.rename_hop_tag([{'n':1, 'ang':90, 'tag': b'ba', 'tag_new': b'u'},
#
# /Users/cpoli/Dropbox/prog/python/TB/TB/eigTB.py in set_hopping(self, list_hop)
#     455         list_n = np.unique([dic['n'] for dic in list_hop])
#     456         for n in list_n:
# --> 457             ind = np.argwhere((self.vec_hop['d'] > self.dist_uni[n] - 1e-3) &
#     458                                        (self.vec_hop['d'] < self.dist_uni[n] + 1e-3))
#     459             ind_up = ind[ind[:, 1] > ind[:, 0]]
#
# IndexError: index 1 is out of bounds for axis 0 with size 0

# %%
lat = grapheneTB()
sys = eigTB(lat=lat)
plot = plotTB(sys=sys)
lat.triangle_zigzag(14)
plot.lattice(ms=6);

# %%
sys = grapheneEig(lat)
plot = plotTB(sys)
sys.set_hop_uni([{'n':1, 't':1.}])

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a');
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
zero_modes = sys.get_intensity_en(en_lims=[-0.1, 0.1])
plot.intensity_area(zero_modes, s=20, plt_hop=True);
# Out:
# 14 states between -0.1 and 0.1
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# # GRAPHENE FLAKES UNDER LINEAR TRIAXIAL STRAIN

# %% [markdown]
# ## Strained Hexagonal Flakes

# %%
lat = grapheneTB()
lat.hexagon_zigzag(5)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
# Out:
# Strain limits: [-0.66666567  0.66666767]

# %% [markdown]
# ### Increasing negative strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[0])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[0]);
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[0])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ### Increasing positive strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[1])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[1])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[1])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ## Strained Triangular Flakes

# %%
lat = grapheneTB()
lat.triangle_zigzag(10)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
# Out:
# Strain limits: [-0.47058724  1.14285814]

# %% [markdown]
# ### Increasing negative strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[0])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[0])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[0])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ### Increasing positive strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[1])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[1])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[1])
sys.get_coor_hop()
plot.lattice_hop(ms=5, lw=1, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ## Pseudo Landau levels in the triangular flake with zigzag terminations

# %%
lat = grapheneTB()
lat.triangle_zigzag(24)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plot.lattice(ms=5);
plot.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.17777678  0.38095338]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.1, 0.1])
ll1 = sys.get_intensity_en(en_lims=[0.8, 1.2])
ll2 = sys.get_intensity_en(en_lims=[1.2, 1.4])
ll3 = sys.get_intensity_en(en_lims=[1.4, 1.6])
ll4 = sys.get_intensity_en(en_lims=[1.6, 1.8])
ll5 = sys.get_intensity_en(en_lims=[1.8, 2.])
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 24 states between -0.1 and 0.1
# 23 states between 0.8 and 1.2
# 22 states between 1.2 and 1.4
# 21 states between 1.4 and 1.6
# 20 states between 1.6 and 1.8
# 19 states between 1.8 and 2.0
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
plot.intensity_area(ll3, s=20, plt_hop=True);
plot.intensity_area(ll4, s=20, plt_hop=True);
plot.intensity_area(ll5, s=20, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Pseudo Landau levels in the hexagonal flake with zigzag terminations

# %%
lat = grapheneTB()
lat.hexagon_zigzag(10)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plot.lattice(ms=5);
plot.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.2962953  0.2962973]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(en_lims=[0.6, 1.])
ll2 = sys.get_intensity_en(en_lims=[1., 1.3])
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 60 states between -0.2 and 0.2
# 29 states between 0.6 and 1.0
# 25 states between 1.0 and 1.3
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Pseudo Landau levels in the squared flake

# %%
lat = grapheneTB()
lat.square(n=30)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plot.lattice(ms=5);
plot.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.2962953  0.2962973]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2., 2.]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.6, 0.6])
ll1 = sys.get_intensity_en(en_lims=[0.6, 1.])
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
# Out:
# 58 states between -0.6 and 0.6
# 28 states between 0.6 and 1.0
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Pseudo Landau levels in the circular flake

# %%
lat = grapheneTB()
lat.circle(22)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plot.lattice(ms=5);
plot.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.26666567  0.26666767]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2., 2.]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(en_lims=[0.5, 0.9])
ll2 = sys.get_intensity_en(en_lims=[0.9, 1.3])
plot.intensity_area(ll0, s=15, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 60 states between -0.2 and 0.2
# 32 states between 0.5 and 0.9
# 28 states between 0.9 and 1.3
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Pseudo Landau levels in the triangular flake with armchair terminations

# %%
lat = grapheneTB()
lat.triangle_armchair(n=14)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plot.lattice(ms=5);
plot.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.20512721  0.20512921]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-1., 1.]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.6, 0.6])
plot.intensity_area(ll0, s=20, plt_hop=True);
# Out:
# 54 states between -0.6 and 0.6
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Pseudo Landau levels in the hexagonal flake with armchair terminations

# %%
lat = grapheneTB()
lat.hexagon_armchair(7)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plot.lattice(ms=5);
plot.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.22222122  0.22222322]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.5, 0.5])
ll1 = sys.get_intensity_en(en_lims=[0.6, 0.9])
ll2 = sys.get_intensity_en(en_lims=[.9, 1.15])
plot.intensity_area(ll0, s=15, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 54 states between -0.2 and 0.2
# 44 states between 0.6 and 1.0
# 37 states between 1.0 and 1.3
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Vacancy defect leading to localized states between Laudau levels

# %% [markdown]
# ### site A at the center of mass removed

# %%
lat = grapheneTB()
lat.triangle_zigzag(25)
lat.remove_sites([lat.sites//2])
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
plot.lattice(ms=5);
# Out:
# [(0.0, 0.0, b'a') (0.86602499999999999999, 0.5, b'b')
#  (0.86602499999999999999, 1.5, b'a') (1.732051, 0.0, b'a')
#  (1.732051, 2.0, b'b') (1.732051, 3.0, b'a') (2.598076, 0.5, b'b')
#  (2.598076, 1.5, b'a') (2.598076, 3.5, b'b') (2.598076, 4.5, b'a')
#  (3.464102, 0.0, b'a') (3.464102, 2.0, b'b') (3.464102, 3.0, b'a')
#  (3.464102, 5.0, b'b') (3.464102, 6.0, b'a')
#  (4.3301269999999999999, 0.5, b'b') (4.3301269999999999999, 1.5, b'a')
#  (4.3301269999999999999, 3.5, b'b') (4.3301269999999999999, 4.5, b'a')
#  (4.3301269999999999999, 6.5, b'b') (4.3301269999999999999, 7.5, b'a')
#  (5.196152, 0.0, b'a') (5.196152, 2.0, b'b') (5.196152, 3.0, b'a')
#  (5.196152, 5.0, b'b') (5.196152, 6.0, b'a') (5.196152, 8.0, b'b')
#  (5.196152, 9.0, b'a') (6.0621780000000000002, 0.5, b'b')
#  (6.0621780000000000002, 1.5, b'a') (6.0621780000000000002, 3.5, b'b')
#  (6.0621780000000000002, 4.5, b'a') (6.0621780000000000002, 6.5, b'b')
#  (6.0621780000000000002, 7.5, b'a') (6.0621780000000000002, 9.5, b'b')
#  (6.0621780000000000002, 10.5, b'a') (6.9282029999999999999, 0.0, b'a')
#  (6.9282029999999999999, 2.0, b'b') (6.9282029999999999999, 3.0, b'a')
#  (6.9282029999999999999, 5.0, b'b') (6.9282029999999999999, 6.0, b'a')
#  (19.918583999999999999, 34.5, b'a') (20.78461, 0.0, b'a')
#  (20.78461, 2.0, b'b') (20.78461, 3.0, b'a') (20.78461, 5.0, b'b')
#  (20.78461, 6.0, b'a') (20.78461, 8.0, b'b') (20.78461, 9.0, b'a')
#  (20.78461, 11.0, b'b') (20.78461, 12.0, b'a') (20.78461, 14.0, b'b')
#  (20.78461, 15.0, b'a') (20.78461, 17.0, b'b') (20.78461, 20.0, b'b')
#  (20.78461, 21.0, b'a') (20.78461, 23.0, b'b') (20.78461, 24.0, b'a')
#  (20.78461, 26.0, b'b') (20.78461, 27.0, b'a') (20.78461, 29.0, b'b')
#  (20.78461, 30.0, b'a') (20.78461, 32.0, b'b') (20.78461, 33.0, b'a')
#  (20.78461, 35.0, b'b') (20.78461, 36.0, b'a') (21.650635, 0.5, b'b')
#  (21.650635, 1.5, b'a') (21.650635, 3.5, b'b') (21.650635, 4.5, b'a')
#  (21.650635, 6.5, b'b') (21.650635, 7.5, b'a') (21.650635, 9.5, b'b')
#  (21.650635, 10.5, b'a') (21.650635, 12.5, b'b') (21.650635, 13.5, b'a')
#  (21.650635, 15.5, b'b') (21.650635, 16.5, b'a') (21.650635, 18.5, b'b')
#  (21.650635, 19.5, b'a') (21.650635, 21.5, b'b') (21.650635, 22.5, b'a')
#  (21.650635, 24.5, b'b') (21.650635, 25.5, b'a') (21.650635, 27.5, b'b')
#  (21.650635, 28.5, b'a') (21.650635, 30.5, b'b') (21.650635, 31.5, b'a')
#  (21.650635, 33.5, b'b') (21.650635, 34.5, b'a')
#  (22.516659999999999999, 0.0, b'a') (22.516659999999999999, 2.0, b'b')
#  (22.516659999999999999, 3.0, b'a') (22.516659999999999999, 5.0, b'b')
#  (22.516659999999999999, 6.0, b'a') (22.516659999999999999, 8.0, b'b')
#  (22.516659999999999999, 9.0, b'a') (22.516659999999999999, 11.0, b'b')
#  (22.516659999999999999, 12.0, b'a') (22.516659999999999999, 14.0, b'b')
#  (22.516659999999999999, 15.0, b'a') (22.516659999999999999, 17.0, b'b')
#  (22.516659999999999999, 18.0, b'a') (22.516659999999999999, 20.0, b'b')
#  (22.516659999999999999, 21.0, b'a') (22.516659999999999999, 23.0, b'b')
#  (22.516659999999999999, 24.0, b'a') (22.516659999999999999, 26.0, b'b')
#  (22.516659999999999999, 27.0, b'a') (22.516659999999999999, 29.0, b'b')
#  (22.516659999999999999, 30.0, b'a') (22.516659999999999999, 32.0, b'b')
#  (22.516659999999999999, 33.0, b'a') (23.382686, 0.5, b'b')
#  (23.382686, 1.5, b'a') (23.382686, 3.5, b'b') (23.382686, 4.5, b'a')
#  (23.382686, 6.5, b'b') (23.382686, 7.5, b'a') (23.382686, 9.5, b'b')
#  (23.382686, 10.5, b'a') (23.382686, 12.5, b'b') (23.382686, 13.5, b'a')
#  (23.382686, 15.5, b'b') (23.382686, 16.5, b'a') (23.382686, 18.5, b'b')
#  (23.382686, 19.5, b'a') (23.382686, 21.5, b'b') (23.382686, 22.5, b'a')
#  (23.382686, 24.5, b'b') (23.382686, 25.5, b'a') (23.382686, 27.5, b'b')
#  (27.712813, 18.0, b'a') (27.712813, 20.0, b'b') (27.712813, 21.0, b'a')
#  (27.712813, 23.0, b'b') (27.712813, 24.0, b'a') (28.578838, 0.5, b'b')
#  (28.578838, 1.5, b'a') (28.578838, 3.5, b'b') (28.578838, 4.5, b'a')
#  (28.578838, 6.5, b'b') (28.578838, 7.5, b'a') (28.578838, 9.5, b'b')
#  (28.578838, 10.5, b'a') (28.578838, 12.5, b'b') (28.578838, 13.5, b'a')
#  (28.578838, 15.5, b'b') (28.578838, 16.5, b'a') (28.578838, 18.5, b'b')
#  (28.578838, 19.5, b'a') (28.578838, 21.5, b'b') (28.578838, 22.5, b'a')
#  (29.444864000000000001, 0.0, b'a') (29.444864000000000001, 2.0, b'b')
#  (29.444864000000000001, 3.0, b'a') (29.444864000000000001, 5.0, b'b')
#  (29.444864000000000001, 6.0, b'a') (29.444864000000000001, 8.0, b'b')
#  (29.444864000000000001, 9.0, b'a') (29.444864000000000001, 11.0, b'b')
#  (29.444864000000000001, 12.0, b'a') (29.444864000000000001, 14.0, b'b')
#  (29.444864000000000001, 15.0, b'a') (29.444864000000000001, 17.0, b'b')
#  (29.444864000000000001, 18.0, b'a') (29.444864000000000001, 20.0, b'b')
#  (29.444864000000000001, 21.0, b'a') (30.310889, 0.5, b'b')
#  (30.310889, 1.5, b'a') (30.310889, 3.5, b'b') (30.310889, 4.5, b'a')
#  (30.310889, 6.5, b'b') (30.310889, 7.5, b'a') (30.310889, 9.5, b'b')
#  (30.310889, 10.5, b'a') (30.310889, 12.5, b'b') (30.310889, 13.5, b'a')
#  (30.310889, 15.5, b'b') (30.310889, 16.5, b'a') (30.310889, 18.5, b'b')
#  (30.310889, 19.5, b'a') (31.176914999999999999, 0.0, b'a')
#  (31.176914999999999999, 2.0, b'b') (31.176914999999999999, 3.0, b'a')
#  (31.176914999999999999, 5.0, b'b') (31.176914999999999999, 6.0, b'a')
#  (31.176914999999999999, 8.0, b'b') (31.176914999999999999, 9.0, b'a')
#  (31.176914999999999999, 11.0, b'b') (31.176914999999999999, 12.0, b'a')
#  (31.176914999999999999, 14.0, b'b') (31.176914999999999999, 15.0, b'a')
#  (31.176914999999999999, 17.0, b'b') (31.176914999999999999, 18.0, b'a')
#  (32.042939999999999999, 0.5, b'b') (32.042939999999999999, 1.5, b'a')
#  (32.042939999999999999, 3.5, b'b') (32.042939999999999999, 4.5, b'a')
#  (32.042939999999999999, 6.5, b'b') (32.042939999999999999, 7.5, b'a')
#  (32.042939999999999999, 9.5, b'b') (32.042939999999999999, 10.5, b'a')
#  (32.042939999999999999, 12.5, b'b') (32.042939999999999999, 13.5, b'a')
#  (32.042939999999999999, 15.5, b'b') (32.042939999999999999, 16.5, b'a')
#  (32.908964999999999999, 0.0, b'a') (32.908964999999999999, 2.0, b'b')
#  (32.908964999999999999, 3.0, b'a') (32.908964999999999999, 5.0, b'b')
#  (32.908964999999999999, 6.0, b'a') (32.908964999999999999, 8.0, b'b')
#  (32.908964999999999999, 9.0, b'a') (32.908964999999999999, 11.0, b'b')
#  (32.908964999999999999, 12.0, b'a') (32.908964999999999999, 14.0, b'b')
#  (32.908964999999999999, 15.0, b'a') (33.774990999999999999, 0.5, b'b')
#  (33.774990999999999999, 1.5, b'a') (33.774990999999999999, 3.5, b'b')
#  (33.774990999999999999, 4.5, b'a') (33.774990999999999999, 6.5, b'b')
#  (33.774990999999999999, 7.5, b'a') (33.774990999999999999, 9.5, b'b')
#  (33.774990999999999999, 10.5, b'a') (33.774990999999999999, 12.5, b'b')
#  (33.774990999999999999, 13.5, b'a') (34.641015999999999999, 0.0, b'a')
#  (34.641015999999999999, 2.0, b'b') (34.641015999999999999, 3.0, b'a')
#  (34.641015999999999999, 5.0, b'b') (34.641015999999999999, 6.0, b'a')
#  (34.641015999999999999, 8.0, b'b') (34.641015999999999999, 9.0, b'a')
#  (34.641015999999999999, 11.0, b'b') (34.641015999999999999, 12.0, b'a')
#  (35.507042, 0.5, b'b') (35.507042, 1.5, b'a') (35.507042, 3.5, b'b')
#  (35.507042, 4.5, b'a') (35.507042, 6.5, b'b') (35.507042, 7.5, b'a')
#  (35.507042, 9.5, b'b') (35.507042, 10.5, b'a')
#  (36.373066999999999999, 0.0, b'a') (36.373066999999999999, 2.0, b'b')
#  (36.373066999999999999, 3.0, b'a') (36.373066999999999999, 5.0, b'b')
#  (36.373066999999999999, 6.0, b'a') (36.373066999999999999, 8.0, b'b')
#  (36.373066999999999999, 9.0, b'a') (37.239091999999999999, 0.5, b'b')
#  (37.239091999999999999, 1.5, b'a') (37.239091999999999999, 3.5, b'b')
#  (37.239091999999999999, 4.5, b'a') (37.239091999999999999, 6.5, b'b')
#  (37.239091999999999999, 7.5, b'a') (38.105118, 0.0, b'a')
#  (38.105118, 2.0, b'b') (38.105118, 3.0, b'a') (38.105118, 5.0, b'b')
#  (38.105118, 6.0, b'a') (38.971142999999999999, 0.5, b'b')
#  (38.971142999999999999, 1.5, b'a') (38.971142999999999999, 3.5, b'b')
#  (38.971142999999999999, 4.5, b'a') (39.837169, 0.0, b'a')
#  (39.837169, 2.0, b'b') (39.837169, 3.0, b'a') (40.703194, 0.5, b'b')
#  (40.703194, 1.5, b'a') (41.569218999999999999, 0.0, b'a')]
# [[ 0.0  0.5  1.5 ...,  0.5  1.5  0.0]
#  [-0.5  0.0  1.0 ...,  0.0  1.0 -0.5]
#  [-1.5 -1.0  0.0 ..., -1.0  0.0 -1.5]
#  ...,
#  [-0.5  0.0  1.0 ...,  0.0  1.0 -0.5]
#  [-1.5 -1.0  0.0 ..., -1.0  0.0 -1.5]
#  [ 0.0  0.5  1.5 ...,  0.5  1.5  0.0]]
# [[(0.0, 0.0) (1.0, 30.0) (1.732, 60.0) ...,
#   (40.705999999999999999, 0.70400000000000000002)
#   (40.731, 2.1109999999999999999) (41.568999999999999999, 0.0)]
#  [(1.0, -150.0) (0.0, 0.0) (1.0, 90.0) ..., (39.837000000000000001, 0.0)
#   (39.849999999999999999, 1.438)
#   (40.705999999999999999, -0.70400000000000000002)]
#  [(1.732, -120.0) (1.0, -90.0) (0.0, 0.0) ...,
#   (39.849999999999999999, -1.438) (39.837000000000000001, 0.0)
#   (40.731, -2.1109999999999999999)]
#  ...,
#  [(40.705999999999999999, -179.296) (39.837000000000000001, 180.0)
#   (39.849999999999999999, 178.562) ..., (0.0, 0.0) (1.0, 90.0) (1.0, -30.0)]
#  [(40.731, -177.889) (39.849999999999999999, -178.562)
#   (39.837000000000000001, 180.0) ..., (1.0, -90.0) (0.0, 0.0)
#   (1.732, -60.0)]
#  [(41.568999999999999999, 180.0) (40.705999999999999999, 179.296)
#   (40.731, 177.889) ..., (1.0, 150.0) (1.732, 120.0) (0.0, 0.0)]]
# Strain limits: [-0.17014215  0.36395551]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(ms=8, tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(en_lims=[.8, 1.])
ll2 = sys.get_intensity_en(en_lims=[1.2, 1.3])
v0 = sys.get_intensity_en(en_lims=[0.5, 0.6])
v1 = sys.get_intensity_en(en_lims=[1., 1.1])
v2 = sys.get_intensity_en(en_lims=[1.35, 1.4])
# Out:
# 24 states between -0.2 and 0.2
# 23 states between 0.8 and 1.0
# 22 states between 1.2 and 1.3
# 1 states between 0.5 and 0.6
# 1 states between 1.0 and 1.1
# 1 states between 1.35 and 1.4

# %%
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
plot.intensity_area(v0, s=40, plt_hop=True);
plot.intensity_area(v1, s=40, plt_hop=True);
plot.intensity_area(v2, s=40, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### site B at the center of mass removed

# %%
lat = grapheneTB()
lat.triangle_zigzag(24)
lat.remove_sites([lat.sites//2])
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
plot.lattice(ms=5);
# Out:
# [(0.0, 0.0, b'a') (0.86602499999999999999, 0.5, b'b')
#  (0.86602499999999999999, 1.5, b'a') (1.732051, 0.0, b'a')
#  (1.732051, 2.0, b'b') (1.732051, 3.0, b'a') (2.598076, 0.5, b'b')
#  (2.598076, 1.5, b'a') (2.598076, 3.5, b'b') (2.598076, 4.5, b'a')
#  (3.464102, 0.0, b'a') (3.464102, 2.0, b'b') (3.464102, 3.0, b'a')
#  (3.464102, 5.0, b'b') (3.464102, 6.0, b'a')
#  (4.3301269999999999999, 0.5, b'b') (4.3301269999999999999, 1.5, b'a')
#  (4.3301269999999999999, 3.5, b'b') (4.3301269999999999999, 4.5, b'a')
#  (4.3301269999999999999, 6.5, b'b') (4.3301269999999999999, 7.5, b'a')
#  (5.196152, 0.0, b'a') (5.196152, 2.0, b'b') (5.196152, 3.0, b'a')
#  (5.196152, 5.0, b'b') (5.196152, 6.0, b'a') (5.196152, 8.0, b'b')
#  (5.196152, 9.0, b'a') (6.0621780000000000002, 0.5, b'b')
#  (19.918583999999999999, 16.5, b'a') (19.918583999999999999, 19.5, b'a')
#  (19.918583999999999999, 21.5, b'b') (19.918583999999999999, 22.5, b'a')
#  (19.918583999999999999, 24.5, b'b') (19.918583999999999999, 25.5, b'a')
#  (19.918583999999999999, 27.5, b'b') (19.918583999999999999, 28.5, b'a')
#  (19.918583999999999999, 30.5, b'b') (19.918583999999999999, 31.5, b'a')
#  (19.918583999999999999, 33.5, b'b') (19.918583999999999999, 34.5, b'a')
#  (20.78461, 0.0, b'a') (20.78461, 2.0, b'b') (20.78461, 3.0, b'a')
#  (20.78461, 5.0, b'b') (20.78461, 6.0, b'a') (20.78461, 8.0, b'b')
#  (20.78461, 9.0, b'a') (20.78461, 11.0, b'b') (20.78461, 12.0, b'a')
#  (20.78461, 14.0, b'b') (20.78461, 15.0, b'a') (20.78461, 17.0, b'b')
#  (20.78461, 18.0, b'a') (20.78461, 20.0, b'b') (20.78461, 21.0, b'a')
#  (20.78461, 23.0, b'b') (20.78461, 24.0, b'a') (20.78461, 26.0, b'b')
#  (20.78461, 27.0, b'a') (20.78461, 29.0, b'b') (20.78461, 30.0, b'a')
#  (20.78461, 32.0, b'b') (20.78461, 33.0, b'a') (21.650635, 0.5, b'b')
#  (21.650635, 1.5, b'a') (21.650635, 3.5, b'b') (21.650635, 4.5, b'a')
#  (21.650635, 6.5, b'b') (21.650635, 7.5, b'a') (21.650635, 9.5, b'b')
#  (21.650635, 10.5, b'a') (21.650635, 12.5, b'b') (21.650635, 13.5, b'a')
#  (21.650635, 15.5, b'b') (21.650635, 16.5, b'a') (21.650635, 18.5, b'b')
#  (21.650635, 19.5, b'a') (21.650635, 21.5, b'b') (21.650635, 22.5, b'a')
#  (21.650635, 24.5, b'b') (21.650635, 25.5, b'a') (21.650635, 27.5, b'b')
#  (21.650635, 28.5, b'a') (21.650635, 30.5, b'b') (21.650635, 31.5, b'a')
#  (22.516659999999999999, 0.0, b'a') (22.516659999999999999, 2.0, b'b')
#  (22.516659999999999999, 3.0, b'a') (22.516659999999999999, 5.0, b'b')
#  (22.516659999999999999, 6.0, b'a') (22.516659999999999999, 8.0, b'b')
#  (22.516659999999999999, 9.0, b'a') (22.516659999999999999, 11.0, b'b')
#  (22.516659999999999999, 12.0, b'a') (22.516659999999999999, 14.0, b'b')
#  (22.516659999999999999, 15.0, b'a') (22.516659999999999999, 17.0, b'b')
#  (22.516659999999999999, 18.0, b'a') (22.516659999999999999, 20.0, b'b')
#  (22.516659999999999999, 21.0, b'a') (22.516659999999999999, 23.0, b'b')
#  (22.516659999999999999, 24.0, b'a') (22.516659999999999999, 26.0, b'b')
#  (22.516659999999999999, 27.0, b'a') (22.516659999999999999, 29.0, b'b')
#  (22.516659999999999999, 30.0, b'a') (23.382686, 0.5, b'b')
#  (23.382686, 1.5, b'a') (23.382686, 3.5, b'b') (23.382686, 4.5, b'a')
#  (23.382686, 6.5, b'b') (23.382686, 7.5, b'a') (23.382686, 9.5, b'b')
#  (23.382686, 10.5, b'a') (23.382686, 12.5, b'b') (23.382686, 13.5, b'a')
#  (27.712813, 20.0, b'b') (27.712813, 21.0, b'a') (28.578838, 0.5, b'b')
#  (28.578838, 1.5, b'a') (28.578838, 3.5, b'b') (28.578838, 4.5, b'a')
#  (28.578838, 6.5, b'b') (28.578838, 7.5, b'a') (28.578838, 9.5, b'b')
#  (28.578838, 10.5, b'a') (28.578838, 12.5, b'b') (28.578838, 13.5, b'a')
#  (28.578838, 15.5, b'b') (28.578838, 16.5, b'a') (28.578838, 18.5, b'b')
#  (28.578838, 19.5, b'a') (29.444864000000000001, 0.0, b'a')
#  (29.444864000000000001, 2.0, b'b') (29.444864000000000001, 3.0, b'a')
#  (29.444864000000000001, 5.0, b'b') (29.444864000000000001, 6.0, b'a')
#  (29.444864000000000001, 8.0, b'b') (29.444864000000000001, 9.0, b'a')
#  (29.444864000000000001, 11.0, b'b') (29.444864000000000001, 12.0, b'a')
#  (29.444864000000000001, 14.0, b'b') (29.444864000000000001, 15.0, b'a')
#  (29.444864000000000001, 17.0, b'b') (29.444864000000000001, 18.0, b'a')
#  (30.310889, 0.5, b'b') (30.310889, 1.5, b'a') (30.310889, 3.5, b'b')
#  (30.310889, 4.5, b'a') (30.310889, 6.5, b'b') (30.310889, 7.5, b'a')
#  (30.310889, 9.5, b'b') (30.310889, 10.5, b'a') (30.310889, 12.5, b'b')
#  (30.310889, 13.5, b'a') (30.310889, 15.5, b'b') (30.310889, 16.5, b'a')
#  (31.176914999999999999, 0.0, b'a') (31.176914999999999999, 2.0, b'b')
#  (31.176914999999999999, 3.0, b'a') (31.176914999999999999, 5.0, b'b')
#  (31.176914999999999999, 6.0, b'a') (31.176914999999999999, 8.0, b'b')
#  (31.176914999999999999, 9.0, b'a') (31.176914999999999999, 11.0, b'b')
#  (31.176914999999999999, 12.0, b'a') (31.176914999999999999, 14.0, b'b')
#  (31.176914999999999999, 15.0, b'a') (32.042939999999999999, 0.5, b'b')
#  (32.042939999999999999, 1.5, b'a') (32.042939999999999999, 3.5, b'b')
#  (32.042939999999999999, 4.5, b'a') (32.042939999999999999, 6.5, b'b')
#  (32.042939999999999999, 7.5, b'a') (32.042939999999999999, 9.5, b'b')
#  (32.042939999999999999, 10.5, b'a') (32.042939999999999999, 12.5, b'b')
#  (32.042939999999999999, 13.5, b'a') (32.908964999999999999, 0.0, b'a')
#  (32.908964999999999999, 2.0, b'b') (32.908964999999999999, 3.0, b'a')
#  (32.908964999999999999, 5.0, b'b') (32.908964999999999999, 6.0, b'a')
#  (32.908964999999999999, 8.0, b'b') (32.908964999999999999, 9.0, b'a')
#  (32.908964999999999999, 11.0, b'b') (32.908964999999999999, 12.0, b'a')
#  (33.774990999999999999, 0.5, b'b') (33.774990999999999999, 1.5, b'a')
#  (33.774990999999999999, 3.5, b'b') (33.774990999999999999, 4.5, b'a')
#  (33.774990999999999999, 6.5, b'b') (33.774990999999999999, 7.5, b'a')
#  (33.774990999999999999, 9.5, b'b') (33.774990999999999999, 10.5, b'a')
#  (34.641015999999999999, 0.0, b'a') (34.641015999999999999, 2.0, b'b')
#  (34.641015999999999999, 3.0, b'a') (34.641015999999999999, 5.0, b'b')
#  (34.641015999999999999, 6.0, b'a') (34.641015999999999999, 8.0, b'b')
#  (34.641015999999999999, 9.0, b'a') (35.507042, 0.5, b'b')
#  (35.507042, 1.5, b'a') (35.507042, 3.5, b'b') (35.507042, 4.5, b'a')
#  (35.507042, 6.5, b'b') (35.507042, 7.5, b'a')
#  (36.373066999999999999, 0.0, b'a') (36.373066999999999999, 2.0, b'b')
#  (36.373066999999999999, 3.0, b'a') (36.373066999999999999, 5.0, b'b')
#  (36.373066999999999999, 6.0, b'a') (37.239091999999999999, 0.5, b'b')
#  (37.239091999999999999, 1.5, b'a') (37.239091999999999999, 3.5, b'b')
#  (37.239091999999999999, 4.5, b'a') (38.105118, 0.0, b'a')
#  (38.105118, 2.0, b'b') (38.105118, 3.0, b'a')
#  (38.971142999999999999, 0.5, b'b') (38.971142999999999999, 1.5, b'a')
#  (39.837169, 0.0, b'a')]
# [[ 0.0  0.5  1.5 ...,  0.5  1.5  0.0]
#  [-0.5  0.0  1.0 ...,  0.0  1.0 -0.5]
#  [-1.5 -1.0  0.0 ..., -1.0  0.0 -1.5]
#  ...,
#  [-0.5  0.0  1.0 ...,  0.0  1.0 -0.5]
#  [-1.5 -1.0  0.0 ..., -1.0  0.0 -1.5]
#  [ 0.0  0.5  1.5 ...,  0.5  1.5  0.0]]
# [[(0.0, 0.0) (1.0, 30.0) (1.732, 60.0) ...,
#   (38.974000000000000001, 0.73500000000000000001)
#   (39.0, 2.2039999999999999999) (39.837000000000000001, 0.0)]
#  [(1.0, -150.0) (0.0, 0.0) (1.0, 90.0) ..., (38.105, 0.0)
#   (38.118000000000000001, 1.503)
#   (38.974000000000000001, -0.73500000000000000001)]
#  [(1.732, -120.0) (1.0, -90.0) (0.0, 0.0) ...,
#   (38.118000000000000001, -1.503) (38.105, 0.0)
#   (39.0, -2.2039999999999999999)]
#  ...,
#  [(38.974000000000000001, -179.265) (38.105, 180.0)
#   (38.118000000000000001, 178.497) ..., (0.0, 0.0) (1.0, 90.0) (1.0, -30.0)]
#  [(39.0, -177.796) (38.118000000000000001, -178.497) (38.105, 180.0) ...,
#   (1.0, -90.0) (0.0, 0.0) (1.732, -60.0)]
#  [(39.837000000000000001, 180.0) (38.974000000000000001, 179.265)
#   (39.0, 177.796) ..., (1.0, 150.0) (1.732, 120.0) (0.0, 0.0)]]
# Strain limits: [-0.17768064  0.38139558]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(en_lims=[.8, 1.])
ll2 = sys.get_intensity_en(en_lims=[1.2, 1.4])
v0 = sys.get_intensity_en(en_lims=[1., 1.1])
v1 = sys.get_intensity_en(en_lims=[1.35, 1.45])
v2 = sys.get_intensity_en(en_lims=[1.6, 1.65])
# Out:
# 25 states between -0.2 and 0.2
# 22 states between 0.8 and 1.0
# 22 states between 1.2 and 1.4
# 1 states between 1.0 and 1.1
# 1 states between 1.35 and 1.45
# 1 states between 1.6 and 1.65

# %%
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);

# %%
plot.intensity_area(v0, s=40, plt_hop=True);
plot.intensity_area(v1, s=40, plt_hop=True);
plot.intensity_area(v2, s=40, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Vacancy defect leading to localized states between Laudau levels

# %%
lat = grapheneTB()
lat.triangle_zigzag(24)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.set_vortex()
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# [(0.0, 0.0, b'a') (0.86602499999999999999, 0.5, b'b')
#  (0.86602499999999999999, 1.5, b'a') (1.732051, 0.0, b'a')
#  (1.732051, 2.0, b'b') (1.732051, 3.0, b'a') (2.598076, 0.5, b'b')
#  (2.598076, 1.5, b'a') (2.598076, 3.5, b'b') (2.598076, 4.5, b'a')
#  (3.464102, 0.0, b'a') (3.464102, 2.0, b'b') (3.464102, 3.0, b'a')
#  (3.464102, 5.0, b'b') (3.464102, 6.0, b'a')
#  (4.3301269999999999999, 0.5, b'b') (4.3301269999999999999, 1.5, b'a')
#  (4.3301269999999999999, 3.5, b'b') (4.3301269999999999999, 4.5, b'a')
#  (4.3301269999999999999, 6.5, b'b') (4.3301269999999999999, 7.5, b'a')
#  (5.196152, 0.0, b'a') (5.196152, 2.0, b'b') (5.196152, 3.0, b'a')
#  (5.196152, 5.0, b'b') (5.196152, 6.0, b'a') (5.196152, 8.0, b'b')
#  (5.196152, 9.0, b'a') (6.0621780000000000002, 0.5, b'b')
#  (6.0621780000000000002, 1.5, b'a') (6.0621780000000000002, 3.5, b'b')
#  (6.0621780000000000002, 4.5, b'a') (6.0621780000000000002, 6.5, b'b')
#  (6.0621780000000000002, 7.5, b'a') (6.0621780000000000002, 9.5, b'b')
#  (6.0621780000000000002, 10.5, b'a') (6.9282029999999999999, 0.0, b'a')
#  (6.9282029999999999999, 2.0, b'b') (6.9282029999999999999, 3.0, b'a')
#  (6.9282029999999999999, 5.0, b'b') (6.9282029999999999999, 6.0, b'a')
#  (6.9282029999999999999, 8.0, b'b') (6.9282029999999999999, 9.0, b'a')
#  (6.9282029999999999999, 11.0, b'b') (6.9282029999999999999, 12.0, b'a')
#  (7.7942290000000000001, 0.5, b'b') (7.7942290000000000001, 1.5, b'a')
#  (7.7942290000000000001, 3.5, b'b') (7.7942290000000000001, 4.5, b'a')
#  (7.7942290000000000001, 6.5, b'b') (7.7942290000000000001, 7.5, b'a')
#  (7.7942290000000000001, 9.5, b'b') (7.7942290000000000001, 10.5, b'a')
#  (7.7942290000000000001, 12.5, b'b') (7.7942290000000000001, 13.5, b'a')
#  (8.6602539999999999997, 0.0, b'a') (8.6602539999999999997, 2.0, b'b')
#  (18.186532999999999999, 7.5, b'a') (18.186532999999999999, 9.5, b'b')
#  (18.186532999999999999, 10.5, b'a') (18.186532999999999999, 12.5, b'b')
#  (18.186532999999999999, 13.5, b'a') (18.186532999999999999, 15.5, b'b')
#  (18.186532999999999999, 16.5, b'a') (18.186532999999999999, 18.5, b'b')
#  (18.186532999999999999, 19.5, b'a') (18.186532999999999999, 21.5, b'b')
#  (18.186532999999999999, 22.5, b'a') (18.186532999999999999, 24.5, b'b')
#  (18.186532999999999999, 25.5, b'a') (18.186532999999999999, 27.5, b'b')
#  (18.186532999999999999, 28.5, b'a') (18.186532999999999999, 30.5, b'b')
#  (18.186532999999999999, 31.5, b'a') (19.052559, 0.0, b'a')
#  (19.052559, 2.0, b'b') (19.052559, 3.0, b'a') (19.052559, 5.0, b'b')
#  (19.052559, 6.0, b'a') (19.052559, 8.0, b'b') (19.052559, 9.0, b'a')
#  (19.052559, 11.0, b'b') (19.052559, 12.0, b'a') (19.052559, 14.0, b'b')
#  (19.052559, 15.0, b'a') (19.052559, 17.0, b'b') (19.052559, 18.0, b'a')
#  (19.052559, 20.0, b'b') (19.052559, 21.0, b'a') (19.052559, 23.0, b'b')
#  (19.052559, 24.0, b'a') (19.052559, 26.0, b'b') (19.052559, 27.0, b'a')
#  (19.052559, 29.0, b'b') (19.052559, 30.0, b'a') (19.052559, 32.0, b'b')
#  (19.052559, 33.0, b'a') (19.918583999999999999, 0.5, b'b')
#  (19.918583999999999999, 1.5, b'a') (19.918583999999999999, 3.5, b'b')
#  (19.918583999999999999, 4.5, b'a') (19.918583999999999999, 6.5, b'b')
#  (19.918583999999999999, 7.5, b'a') (19.918583999999999999, 9.5, b'b')
#  (19.918583999999999999, 10.5, b'a') (19.918583999999999999, 12.5, b'b')
#  (19.918583999999999999, 13.5, b'a') (19.918583999999999999, 15.5, b'b')
#  (19.918583999999999999, 16.5, b'a') (19.918583999999999999, 18.5, b'b')
#  (19.918583999999999999, 19.5, b'a') (19.918583999999999999, 21.5, b'b')
#  (19.918583999999999999, 22.5, b'a') (19.918583999999999999, 24.5, b'b')
#  (19.918583999999999999, 25.5, b'a') (19.918583999999999999, 27.5, b'b')
#  (19.918583999999999999, 28.5, b'a') (19.918583999999999999, 30.5, b'b')
#  (19.918583999999999999, 31.5, b'a') (19.918583999999999999, 33.5, b'b')
#  (19.918583999999999999, 34.5, b'a') (20.78461, 0.0, b'a')
#  (20.78461, 2.0, b'b') (20.78461, 3.0, b'a') (20.78461, 5.0, b'b')
#  (20.78461, 6.0, b'a') (20.78461, 8.0, b'b') (20.78461, 9.0, b'a')
#  (20.78461, 11.0, b'b') (20.78461, 12.0, b'a') (20.78461, 14.0, b'b')
#  (20.78461, 15.0, b'a') (20.78461, 17.0, b'b') (20.78461, 18.0, b'a')
#  (20.78461, 20.0, b'b') (20.78461, 21.0, b'a') (20.78461, 23.0, b'b')
#  (20.78461, 24.0, b'a') (20.78461, 26.0, b'b') (20.78461, 27.0, b'a')
#  (20.78461, 29.0, b'b') (20.78461, 30.0, b'a') (20.78461, 32.0, b'b')
#  (20.78461, 33.0, b'a') (21.650635, 0.5, b'b') (21.650635, 1.5, b'a')
#  (21.650635, 3.5, b'b') (21.650635, 4.5, b'a') (21.650635, 6.5, b'b')
#  (21.650635, 7.5, b'a') (21.650635, 9.5, b'b') (21.650635, 10.5, b'a')
#  (21.650635, 12.5, b'b') (21.650635, 13.5, b'a') (21.650635, 15.5, b'b')
#  (21.650635, 16.5, b'a') (21.650635, 18.5, b'b') (21.650635, 19.5, b'a')
#  (21.650635, 21.5, b'b') (21.650635, 22.5, b'a') (21.650635, 24.5, b'b')
#  (21.650635, 25.5, b'a') (21.650635, 27.5, b'b') (21.650635, 28.5, b'a')
#  (21.650635, 30.5, b'b') (21.650635, 31.5, b'a')
#  (22.516659999999999999, 0.0, b'a') (22.516659999999999999, 2.0, b'b')
#  (22.516659999999999999, 3.0, b'a') (22.516659999999999999, 5.0, b'b')
#  (22.516659999999999999, 6.0, b'a') (22.516659999999999999, 8.0, b'b')
#  (22.516659999999999999, 9.0, b'a') (22.516659999999999999, 11.0, b'b')
#  (22.516659999999999999, 12.0, b'a') (22.516659999999999999, 14.0, b'b')
#  (22.516659999999999999, 15.0, b'a') (22.516659999999999999, 17.0, b'b')
#  (22.516659999999999999, 18.0, b'a') (22.516659999999999999, 20.0, b'b')
#  (22.516659999999999999, 21.0, b'a') (22.516659999999999999, 23.0, b'b')
#  (22.516659999999999999, 24.0, b'a') (22.516659999999999999, 26.0, b'b')
#  (22.516659999999999999, 27.0, b'a') (22.516659999999999999, 29.0, b'b')
#  (22.516659999999999999, 30.0, b'a') (23.382686, 0.5, b'b')
#  (23.382686, 1.5, b'a') (23.382686, 3.5, b'b') (23.382686, 4.5, b'a')
#  (23.382686, 6.5, b'b') (23.382686, 7.5, b'a') (23.382686, 9.5, b'b')
#  (23.382686, 10.5, b'a') (23.382686, 12.5, b'b') (23.382686, 13.5, b'a')
#  (23.382686, 15.5, b'b') (23.382686, 16.5, b'a') (23.382686, 18.5, b'b')
#  (23.382686, 19.5, b'a') (23.382686, 21.5, b'b') (23.382686, 22.5, b'a')
#  (23.382686, 24.5, b'b') (23.382686, 25.5, b'a') (23.382686, 27.5, b'b')
#  (23.382686, 28.5, b'a') (24.248711, 0.0, b'a') (24.248711, 2.0, b'b')
#  (24.248711, 3.0, b'a') (24.248711, 5.0, b'b') (24.248711, 6.0, b'a')
#  (24.248711, 8.0, b'b') (24.248711, 9.0, b'a') (24.248711, 11.0, b'b')
#  (24.248711, 12.0, b'a') (24.248711, 14.0, b'b') (24.248711, 15.0, b'a')
#  (24.248711, 17.0, b'b') (24.248711, 18.0, b'a') (24.248711, 20.0, b'b')
#  (24.248711, 21.0, b'a') (24.248711, 23.0, b'b') (24.248711, 24.0, b'a')
#  (24.248711, 26.0, b'b') (24.248711, 27.0, b'a') (25.114737, 0.5, b'b')
#  (25.114737, 1.5, b'a') (25.114737, 3.5, b'b') (25.114737, 4.5, b'a')
#  (25.114737, 6.5, b'b') (25.114737, 7.5, b'a') (25.114737, 9.5, b'b')
#  (30.310889, 4.5, b'a') (30.310889, 6.5, b'b') (30.310889, 7.5, b'a')
#  (30.310889, 9.5, b'b') (30.310889, 10.5, b'a') (30.310889, 12.5, b'b')
#  (30.310889, 13.5, b'a') (30.310889, 15.5, b'b') (30.310889, 16.5, b'a')
#  (31.176914999999999999, 0.0, b'a') (31.176914999999999999, 2.0, b'b')
#  (31.176914999999999999, 3.0, b'a') (31.176914999999999999, 5.0, b'b')
#  (31.176914999999999999, 6.0, b'a') (31.176914999999999999, 8.0, b'b')
#  (31.176914999999999999, 9.0, b'a') (31.176914999999999999, 11.0, b'b')
#  (31.176914999999999999, 12.0, b'a') (31.176914999999999999, 14.0, b'b')
#  (31.176914999999999999, 15.0, b'a') (32.042939999999999999, 0.5, b'b')
#  (32.042939999999999999, 1.5, b'a') (32.042939999999999999, 3.5, b'b')
#  (32.042939999999999999, 4.5, b'a') (32.042939999999999999, 6.5, b'b')
#  (32.042939999999999999, 7.5, b'a') (32.042939999999999999, 9.5, b'b')
#  (32.042939999999999999, 10.5, b'a') (32.042939999999999999, 12.5, b'b')
#  (32.042939999999999999, 13.5, b'a') (32.908964999999999999, 0.0, b'a')
#  (32.908964999999999999, 2.0, b'b') (32.908964999999999999, 3.0, b'a')
#  (32.908964999999999999, 5.0, b'b') (32.908964999999999999, 6.0, b'a')
#  (32.908964999999999999, 8.0, b'b') (32.908964999999999999, 9.0, b'a')
#  (32.908964999999999999, 11.0, b'b') (32.908964999999999999, 12.0, b'a')
#  (33.774990999999999999, 0.5, b'b') (33.774990999999999999, 1.5, b'a')
#  (33.774990999999999999, 3.5, b'b') (33.774990999999999999, 4.5, b'a')
#  (33.774990999999999999, 6.5, b'b') (33.774990999999999999, 7.5, b'a')
#  (33.774990999999999999, 9.5, b'b') (33.774990999999999999, 10.5, b'a')
#  (34.641015999999999999, 0.0, b'a') (34.641015999999999999, 2.0, b'b')
#  (34.641015999999999999, 3.0, b'a') (34.641015999999999999, 5.0, b'b')
#  (34.641015999999999999, 6.0, b'a') (34.641015999999999999, 8.0, b'b')
#  (34.641015999999999999, 9.0, b'a') (35.507042, 0.5, b'b')
#  (35.507042, 1.5, b'a') (35.507042, 3.5, b'b') (35.507042, 4.5, b'a')
#  (35.507042, 6.5, b'b') (35.507042, 7.5, b'a')
#  (36.373066999999999999, 0.0, b'a') (36.373066999999999999, 2.0, b'b')
#  (36.373066999999999999, 3.0, b'a') (36.373066999999999999, 5.0, b'b')
#  (36.373066999999999999, 6.0, b'a') (37.239091999999999999, 0.5, b'b')
#  (37.239091999999999999, 1.5, b'a') (37.239091999999999999, 3.5, b'b')
#  (37.239091999999999999, 4.5, b'a') (38.105118, 0.0, b'a')
#  (38.105118, 2.0, b'b') (38.105118, 3.0, b'a')
#  (38.971142999999999999, 0.5, b'b') (38.971142999999999999, 1.5, b'a')
#  (39.837169, 0.0, b'a')]
# [[ 0.0  0.5  1.5 ...,  0.5  1.5  0.0]
#  [-0.5  0.0  1.0 ...,  0.0  1.0 -0.5]
#  [-1.5 -1.0  0.0 ..., -1.0  0.0 -1.5]
#  ...,
#  [-0.5  0.0  1.0 ...,  0.0  1.0 -0.5]
#  [-1.5 -1.0  0.0 ..., -1.0  0.0 -1.5]
#  [ 0.0  0.5  1.5 ...,  0.5  1.5  0.0]]
# [[(0.0, 0.0) (1.0, 30.0) (1.732, 60.0) ...,
#   (38.974000000000000001, 0.73500000000000000001)
#   (39.0, 2.2039999999999999999) (39.837000000000000001, 0.0)]
#  [(1.0, -150.0) (0.0, 0.0) (1.0, 90.0) ..., (38.105, 0.0)
#   (38.118000000000000001, 1.503)
#   (38.974000000000000001, -0.73500000000000000001)]
#  [(1.732, -120.0) (1.0, -90.0) (0.0, 0.0) ...,
#   (38.118000000000000001, -1.503) (38.105, 0.0)
#   (39.0, -2.2039999999999999999)]
#  ...,
#  [(38.974000000000000001, -179.265) (38.105, 180.0)
#   (38.118000000000000001, 178.497) ..., (0.0, 0.0) (1.0, 90.0) (1.0, -30.0)]
#  [(39.0, -177.796) (38.118000000000000001, -178.497) (38.105, 180.0) ...,
#   (1.0, -90.0) (0.0, 0.0) (1.732, -60.0)]
#  [(39.837000000000000001, 180.0) (38.974000000000000001, 179.265)
#   (39.0, 177.796) ..., (1.0, 150.0) (1.732, 120.0) (0.0, 0.0)]]
# Strain limits: [-0.17777678  0.38095338]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(en_lims=[.8, 1.])
ll2 = sys.get_intensity_en(en_lims=[1.2, 1.4])
v0 = sys.get_intensity_en(en_lims=[.4, .8])
v1 = sys.get_intensity_en(en_lims=[1., 1.2])
v2 = sys.get_intensity_en(en_lims=[1.4, 1.51])
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 24 states between -0.2 and 0.2
# 21 states between 0.8 and 1.0
# 18 states between 1.2 and 1.4
# 1 states between 0.4 and 0.8
# 3 states between 1.0 and 1.2
# 5 states between 1.4 and 1.51
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
plot.intensity_area(v0, s=20, plt_hop=True);
plot.intensity_area(v1, s=20, plt_hop=True);
plot.intensity_area(v2, s=20, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Hoftstater Butterfly

# %% [markdown]
# ### triangular flake

# %%
lat = grapheneTB()
lat.triangle_zigzag(24)
sys = grapheneEig(lat)
sys.get_butterfly(t=1, N=20)
plot = plotTB(sys)
plot.butterfly();
# Out:
# Strain limits: [-0.17777678  0.38095338]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### hexagonal flake

# %%
lat = grapheneTB()
lat.hexagon_zigzag(10)
sys = grapheneEig(lat)
sys.get_butterfly(t=1, N=20)
plot = plotTB(sys)
plot.butterfly();
# Out:
# Strain limits: [-0.2962953  0.2962973]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### circular flake

# %%
lat = grapheneTB()
lat.circle(20)
sys = grapheneEig(lat)
sys.get_butterfly(t=1, N=30)
plot = plotTB(sys)
plot.butterfly();
# Out:
# Strain limits: [-0.2962953  0.2962973]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
