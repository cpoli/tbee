# %% [markdown]
# # LATTICE CREATION

# %%
from lattice import *
from system import *
from plot import *
from math import pi, sqrt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## dimer chain

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
             {'tag': b'b', 'r0': [1, 0]}]
prim_vec = {'norm': 2, 'angle': 0}

lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='chain')

n1, n2 = 10, 1
lat.get_lattice(n1=n1, n2=n2)
fig_lat = plt.lattice(ms=20, figsize=(10, 2))
sav.fig_lat(fig_lat, 'lattice')

# %% [markdown]
# ## Square lattice

# %% [markdown]
# ###  with 1 site within the unit cell

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}]
prim_vec = {'norm': 2, 'angle': 90}

lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='square')

n1, n2 = 8, 8
lat.get_lattice(n1=n1, n2=n2)
fig_lat = plt.lattice(ms=15)
sav.fig_lat(fig_lat, 'lattice')

# %% [markdown]
# ### with 4 sites per unit cell

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
             {'tag': b'b', 'r0': [1, 0]},
             {'tag': b'c', 'r0': [0, 1]},
             {'tag': b'd', 'r0': [1, 1]}]
prim_vec = {'norm': 2, 'angle': 90}

lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='square_cell4')

n1, n2 = 4, 4
lat.get_lattice(n1=n1, n2=n2)
fig_lat = plt.lattice(ms=15)
sav.fig_lat(fig_lat, 'lattice')

# %% [markdown]
# ## Face-centered square

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
             {'tag': b'b', 'r0': [1, 1]}]
prim_vec = {'norm': 2, 'angle': 90}

lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='face_center_square')

n1, n2 = 8, 8
lat.get_lattice(n1=n1, n2=n2)
lat.boundary_line(cx=0, cy=-1, co=-12.5)
lat.boundary_line(cx=-1, cy=0, co=-12.5)
fig_lat = plt.lattice(ms=15)
sav.fig_lat(fig_lat, 'lattice')

# %% [markdown]
# ## face-centered hexagon

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}]
prim_vec = {'norm': 1, 'angle': 60}
lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='hexa_face_center')

n1, n2 = 8, 8
lat.get_lattice(n1=n1, n2=n2)
fig_lat = plt.lattice(ms=15)
sav.fig_lat(fig_lat, 'lattice')

# %% [markdown]
# ## Lieb lattice

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]},
             {'tag': b'b', 'r0': [1, 0]},
             {'tag': b'c', 'r0': [0, 1]}]
prim_vec = {'norm': 2, 'angle': 90}
lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='lieb')


n1, n2 = 6, 6
lat.get_lattice(n1=n1, n2=n2)
lat.remove_dangling()
fig_lat = plt.lattice(ms=15)
sav.fig_lat(fig_lat, 'lattice_n6_n6')

# %% [markdown]
# ## graphene

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
             {'tag': b'b', 'r0': [0.5*sqrt(3), 0.5]}]
prim_vec = {'norm': sqrt(3), 'angle': 60}

lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='graphene')

n1, n2 = 6, 6
lat.get_lattice(n1=n1, n2=n2)
fig_lat_ind = plt.lattice(ms=15, fs=15, plt_index=True)
sav.fig_lat(fig_lat_ind, 'lattice_ind')

# %%
lat.remove_sites(index=[27, 32, 33, 38, 39, 44])
lat.remove_dangling()
fig_lat_vac = plt.lattice(ms=15)
sav.fig_lat(fig_lat_vac, 'lattice_index_vac')

# %% [markdown]
# ## Kagome lattice

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
             {'tag': b'b', 'r0': [1, 0]},
             {'tag': b'c', 'r0': [0.5, 0.5*sqrt(3)]}]
prim_vec = {'norm': 2, 'angle': 60}

lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='kagome')

n1, n2 = 6, 5
lat.get_lattice(n1=n1, n2=n2)
fig_lat = plt.lattice(ms=15)
sav.fig_lat(fig_lat, 'lattice')

# %% [markdown]
# ## Line centered hexagon

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
             {'tag': b'a', 'r0': [0.5*sqrt(3), 0.5]}, 
             {'tag': b'b', 'r0': [0.25*sqrt(3), 0.25]},
             {'tag': b'b', 'r0': [0.75*sqrt(3), 0.25]},
             {'tag': b'b', 'r0': [0.5*sqrt(3), 1.]}]
prim_vec = {'norm': sqrt(3), 'angle': 60}

lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='graphene_line_center')

n1, n2 = 6, 6
lat.get_lattice(n1=n1, n2=n2)
lat.remove_dangling()
fig_lat_ind = plt.lattice(ms=10)
sav.fig_lat(fig_lat_ind, 'lattice')

# %% [markdown]
# ## ELLIPSOID SHAPES

# %% [markdown]
# ### Circle

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}]
prim_vec = {'norm': 1, 'angle': 90}
lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='square')

n1, n2 = 12, 12
lat.get_lattice(n1=n1, n2=n2)
lat.center()
lat.ellipse_in(a=5.8, b=5.8)
fig_lat = plt.lattice(ms=10);
sav.fig_lat(fig_lat, 'circle')

# %% [markdown]
# ### Ellipse

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}]
prim_vec = {'norm': 1, 'angle': 90}
lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='square')

n1, n2 = 18, 13
lat.get_lattice(n1=n1, n2=n2)
lat.center()
lat.ellipse_in(a=8.8, b=5.8)
fig_lat = plt.lattice(ms=10)
sav.fig_lat(fig_lat, 'ellipse')

# %% [markdown]
# ### circular hole

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}]
prim_vec = {'norm': 1, 'angle': 90}
lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='square')

n1, n2 = 17, 17
lat.get_lattice(n1=n1, n2=n2)
lat.center()
lat.ellipse_out(a=5.5, b=5.5)
fig_lat = plt.lattice(ms=10);
sav.fig_lat(fig_lat, 'circle_remove')

# %% [markdown]
# ### Circular graphene flake

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
             {'tag': b'a', 'r0': [0.5*sqrt(3), 0.5]}]
prim_vec = {'norm': sqrt(3), 'angle': 60}
lat = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys = system(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='graphene')

n1, n2 = 16, 16
lat.get_lattice(n1=n1, n2=n2)
lat.center()
lat.ellipse_in(a=10, b=10)
lat.remove_dangling()
fig_lat = plt.lattice(ms=5, tics=True)
sav.fig_lat(fig_lat, 'circle');

# %% [markdown]
# ## REMOVE SITES

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}]
prim_vec = {'norm': 1, 'angle': 60}
lat1 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys1 = system(lat=lat1)
plt1 = plot(sys=sys1)
sav = save(dir_name='hexa_face_center')

n1, n2 = 7, 7
lat1.get_lattice(n1=n1, n2=n2)
fig_lat1 = plt1.lattice(ms=20, tics=True)
sav.fig_lat(fig_lat1, 'lattice1');

lat2 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys2 = system(lat=lat2)
plt2 = plot(sys=sys2)
n1, n2 = 3, 3
lat2.get_lattice(n1=n1, n2=n2)
lat2.shift_x(shift=3)
lat2.shift_y(shift=sqrt(3))
fig_lat2 = plt2.lattice(ms=20, tics=True)
sav.fig_lat(fig_lat, 'lattice2');

lat1 -= lat2
fig_lat = plt1.lattice(ms=20)
sav.fig_lat(fig_lat, 'ring');

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
                 {'tag': b'b', 'r0': [0.5*sqrt(3), 0.5]}]
prim_vec = {'norm': sqrt(3), 'angle': 60}
lat0 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys0 = system(lat=lat0)
plt0 = plot(sys=sys0)
sav = save(dir_name='graphene')

n1, n2 = 5, 8
lat0.get_lattice(n1=n1, n2=n2)
fig_lat0 = plt0.lattice(ms=10, tics=True);
sav.fig_lat(fig_lat0, 'lattice0');

lat1 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys1 = system(lat=lat1)
plt1 = plot(sys=sys1)
n1, n2 = 2, 2
lat1.get_lattice(n1=n1, n2=n2)
fig_lat1 = plt1.lattice(tics=True);
sav.fig_lat(fig_lat1, 'lattice1');

lat2 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys2 = system(lat=lat2)
plt2 = plot(sys=sys2)
lat2.get_lattice(n1=n1, n2=n2)
lat2.shift_x(2*sqrt(3))
lat2.shift_y(3)
fig_lat2 = plt2.lattice(tics=True);
sav.fig_lat(fig_lat2, 'lattice2');

lat3 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys3 = system(lat=lat3)
plt3 = plot(sys=sys3)
lat3.get_lattice(n1=n1, n2=n2)
lat3.shift_x(4*sqrt(3))
lat3.shift_y(6)
fig_lat3 = plt3.lattice(tics=True);
sav.fig_lat(fig_lat3, 'lattice3');

lat = lat0 - lat1 - lat2 - lat3
sys = system(lat=lat)
plt = plot(sys=sys)
fig_lat_rem = plt.lattice(ms=10);
sav.fig_lat(fig_lat_rem, 'lattice_rem');

# %% [markdown]
# ## ADD SITES

# %%
# run previous cell first
lat = lat3 + lat2 + lat1
sys = system(lat=lat)
plt = plot(sys=sys)
fig_lat_add = plt.lattice(ms=12);
sav.fig_lat(fig_lat_add, 'lattice_add');

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}]
prim_vec = {'norm': 1, 'angle': 90}

# lattice 1 (square)
lat1 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys1 = system(lat=lat1)
plt1 = plot(sys=sys1)
sav = save(dir_name='dumbbell')

n1, n2 = 7, 7
lat1.get_lattice(n1=n1, n2=n2)
fig_lat1 = plt1.lattice(ms=15, tics=True)
sav.fig_lat(fig_lat1, 'lattice1');

# lattice 2 (rectangle)
lat2 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys2 = system(lat=lat2)
plt2 = plot(sys=sys2)
n1, n2 = 6, 3
lat2.get_lattice(n1=n1, n2=n2)
lat2.shift_x(shift=6)
lat2.shift_y(shift=2)
fig_lat2 = plt2.lattice(ms=15, tics=True)
sav.fig_lat(fig_lat2, 'lattice2');

lat1 += lat2
fig_lat3 = plt1.lattice(ms=15, tics=True);
sav.fig_lat(fig_lat3, 'lattice3');

# lattice 3 (square)
lat3 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys3 = system(lat=lat3)
plt3 = plot(sys=sys3)
n1, n2 = 7, 7
lat3.get_lattice(n1=n1, n2=n2)
lat3.shift_x(shift=12)
fig_lat3 = plt3.lattice(ms=15, tics=True)
sav.fig_lat(fig_lat3, 'lattice2');

lat1 += lat3
fig_lat1 = plt1.lattice(ms=15, figsize=(8, 5))
sav.fig_lat(fig_lat1, 'dumbbell');

# %%
unit_cell = [{'tag': b'a', 'r0': [0, 0]}, 
                 {'tag': b'b', 'r0': [0.5*sqrt(3), 0.5]}]
prim_vec = {'norm': sqrt(3), 'angle': 60}
lat1 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys1 = system(lat=lat1)
plt1 = plot(sys=sys1)
sav = save(dir_name='graphene')

# rhombus = 2 triangles
n = 10 # no of plackets along one edge.
lat1.get_lattice(n1=n+2, n2=n+2)
lat1.boundary_line(cx=-sqrt(3), cy=-1, co=-3*(n+1))
fig_lat = plt1.lattice(ms=10, tics=True)
sav.fig_lat(fig_lat1, 'triangle_up');

lat2 = lattice(unit_cell=unit_cell, prim_vec=prim_vec)
sys2 = system(lat=lat2)
plt2 = plot(sys=sys2)
lat2.get_lattice(n1=n+2, n2=n+2)
lat2.boundary_line(cx=-sqrt(3), cy=-1, co=-3*(n+1))
lat2.change_sign_y()
lat2.shift_y(shift=-1)
fig_lat2 = plt2.lattice(ms=10, tics=True)
sav.fig_lat(fig_lat2, 'triangle_down');

lat1 += lat2 
fig_lat = plt1.lattice(ms=10, figsize=(16, 10))
sav.fig_lat(fig_lat, 'rhombus');
