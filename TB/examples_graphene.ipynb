# %% [markdown]
# # GRAPHENE FLAKES

# %%
from graphene import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Quick examples

# %% [markdown]
# ### lattice with nearest and next-nearest hoppings

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.get_lattice(n1=10, n2=10)
plt.lattice(ms=8);

# %%
sys.set_hopping([{'n':1, 't':1.}, {'n':2, 't':.5}])

# %%
sys.get_ham()
sys.get_eig()
plt.spectrum();

# %% [markdown]
# ### lattice with different hopping values

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.get_lattice(n1=6, n2=6)
plt.lattice(ms=8);

# %%
sys.print_hopping(n=2)
# Out:
# 54 different distances between sites:
#
# Distances between sites:
# 1st hopping, length: 1.000
# 	with positive angles:
# 	 [ 30.0  90.0  150.0]
# 2nd hopping, length: 1.732
# 	with positive angles:
# 	 [ 0.0  60.0  120.0]

# %%
sys.set_hopping([{'n': 1, 'ang': 90,'t':2}, 
                 {'n': 1, 'ang': 30,'t':1.5},
                 {'n': 1, 'ang': 150,'t':1}])

# %%
sys.get_coor_hop()
plt.lattice_hop(ms=10);

# %%
sys.get_ham()
sys.get_eig()
plt.spectrum();

# %%
### Triangular flake with zigzag terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(14)
plt.lattice(ms=6);

# %%
sys.set_hopping([{'n':1, 't':1.}])
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola=b'a', fs=15);

# %%
zero_modes = sys.get_intensity_en(lims=[-0.1, 0.1])
plt.intensity_area(zero_modes, s=20, plt_hop=True, title='');
# Out:
# 16 states between -0.1 and 0.1

# %% [markdown]
# # GRAPHENE FLAKES UNDER LINEAR TRIAXIAL STRAIN

# %% [markdown]
# ## Strained Hexagonal Flakes

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

# %%
lat.hexagon_zigzag(5)
lat.center()
betas = sys.get_beta_lims()
# Out:
# 6.0
# Strain limits: [-0.66666567  0.66666767]

# %% [markdown]
# ### Increasing negative strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[0]);
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ### Increasing positive strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ## Strained Triangular Flakes

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(10)
lat.center()
betas = sys.get_beta_lims()
# Out:
# 10.5
# Strain limits: [-0.38095138  0.88888989]

# %% [markdown]
# ### Increasing negative strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ### Increasing positive strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ## Pseudo Landau levels in the triangular flake with zigzag terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(25)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# 25.5
# Strain limits: [-0.15686175  0.33333433]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola=b'a', lims=[1., 1.5], fs=15);

# %%
ll0 = sys.get_intensity_en(lims=[-0.1, 0.1])
ll1 = sys.get_intensity_en(lims=[0.8, 1.])
ll2 = sys.get_intensity_en(lims=[1., 1.4])
ll3 = sys.get_intensity_en(lims=[1.4, 1.6])
ll4 = sys.get_intensity_en(lims=[1.6, 1.8])
ll5 = sys.get_intensity_en(lims=[1.8, 1.9])
ll6 = sys.get_intensity_en(lims=[1.9, 2.])
plt.intensity_area(ll0, s=20, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
plt.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 27 states between -0.1 and 0.1
# 26 states between 0.8 and 1.0
# 25 states between 1.0 and 1.4
# 24 states between 1.4 and 1.6
# 23 states between 1.6 and 1.8
# 22 states between 1.8 and 1.9
# 18 states between 1.9 and 2.0

# %%
plt.intensity_area(ll3, s=20, plt_hop=True);
plt.intensity_area(ll4, s=20, plt_hop=True);
plt.intensity_area(ll5, s=20, plt_hop=True);

# %% [markdown]
# ## Pseudo Landau levels in the hexagonal flake with zigzag terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.hexagon_zigzag(10)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# 13.5
# Strain limits: [-0.2962953  0.2962973]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola=b'a', fs=15, lims=[-2.2, 2.2]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(lims=[0.6, 1.])
ll2 = sys.get_intensity_en(lims=[1., 1.3])
plt.intensity_area(ll0, s=20, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
plt.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 60 states between -0.2 and 0.2
# 29 states between 0.6 and 1.0
# 25 states between 1.0 and 1.3

# %% [markdown]
# ## Pseudo Landau levels in the squared flake

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.square(n=15)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# 12.7495755518
# Strain limits: [-0.31373493  0.31371605]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola=b'a', fs=15, lims=[-2., 2.]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.6, 0.6])
ll1 = sys.get_intensity_en(lims=[0.6, 1.])
plt.intensity_area(ll0, s=20, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
# Out:
# 77 states between -0.6 and 0.6
# 37 states between 0.6 and 1.0

# %% [markdown]
# ## Pseudo Landau levels in the circular flake

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.circle(18)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# 15.0
# Strain limits: [-0.26666567  0.26666767]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola=b'a', fs=15, lims=[-1.5, 1.5]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.3, 0.3])
ll1 = sys.get_intensity_en(lims=[0.5, 1.])
ll2 = sys.get_intensity_en(lims=[1., 1.3])
plt.intensity_area(ll0, s=15, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
plt.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 58 states between -0.3 and 0.3
# 29 states between 0.5 and 1.0
# 28 states between 1.0 and 1.3

# %% [markdown]
# ## Pseudo Landau levels in the triangular flake with armchair terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_armchair(n=14)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# 19.5
# Strain limits: [-0.20512721  0.20512921]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola=b'a', lims=[-1., 1.]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.6, 0.6])
plt.intensity_area(ll0, s=10, plt_hop=True, title='');
# Out:
# 54 states between -0.6 and 0.6

# %% [markdown]
# ## Pseudo Landau levels in the hexagonal flake with armchair terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.hexagon_armchair(7)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# 18.0
# Strain limits: [-0.22222122  0.22222322]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola=b'a', fs=15, lims=[-2.2, 2.2]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.5, 0.5])
ll1 = sys.get_intensity_en(lims=[0.6, 0.9])
ll2 = sys.get_intensity_en(lims=[.9, 1.15])
plt.intensity_area(ll0, s=12, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
plt.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 66 states between -0.5 and 0.5
# 32 states between 0.6 and 0.9
# 28 states between 0.9 and 1.15

# %% [markdown]
# ## Vacancy defect leading to localized states between Laudau levels

# %% [markdown]
# ### site A at the center of mass removed

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(25)
lat.center()
lat.remove_sites([lat.sites//2])
#betas = sys.get_beta_lims()
#sys.set_hop_linear_strain(t=1, beta=betas[1])
plt.lattice(ms=5);

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(ms=8, tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(en_lims=[.8, 1.])
ll2 = sys.get_intensity_en(en_lims=[1.2, 1.3])
v0 = sys.get_intensity_en(en_lims=[0.5, 0.6])
v1 = sys.get_intensity_en(en_lims=[1., 1.1])
v2 = sys.get_intensity_en(en_lims=[1.35, 1.4])
# Out:
# 24 states between -0.2 and 0.2
# 23 states between 0.8 and 1.0
# 22 states between 1.2 and 1.3
# 1 states between 0.5 and 0.6
# 1 states between 1.0 and 1.1
# 1 states between 1.35 and 1.4

# %%
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
plot.intensity_area(v0, s=40, plt_hop=True);
plot.intensity_area(v1, s=40, plt_hop=True);
plot.intensity_area(v2, s=40, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### site B at the center of mass removed

# %%
lat = grapheneTB()
lat.triangle_zigzag(24)
lat.remove_sites([lat.sites//2])
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
plot.lattice(ms=5);
# Out:
# Strain limits: [-0.17768064  0.38139558]

# %%
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(en_lims=[.8, 1.])
ll2 = sys.get_intensity_en(en_lims=[1.2, 1.4])
v0 = sys.get_intensity_en(en_lims=[1., 1.1])
v1 = sys.get_intensity_en(en_lims=[1.35, 1.45])
v2 = sys.get_intensity_en(en_lims=[1.6, 1.65])
# Out:
# 25 states between -0.2 and 0.2
# 22 states between 0.8 and 1.0
# 22 states between 1.2 and 1.4
# 1 states between 1.0 and 1.1
# 1 states between 1.35 and 1.45
# 1 states between 1.6 and 1.65

# %%
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);

# %%
plot.intensity_area(v0, s=40, plt_hop=True);
plot.intensity_area(v1, s=40, plt_hop=True);
plot.intensity_area(v2, s=40, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Vacancy defect leading to localized states between Laudau levels

# %%
lat = grapheneTB()
lat.triangle_zigzag(24)
sys = grapheneEig(lat)
plot = plotTB(sys)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.set_vortex()
sys.get_ham(complex_transpose=True)
sys.get_eig(eigenvec=True)
plot.spectrum(tag_pola=b'a', en_lims=[-2.2, 2.2]);
# Out:
# Strain limits: [-0.17777678  0.38095338]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
ll0 = sys.get_intensity_en(en_lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(en_lims=[.8, 1.])
ll2 = sys.get_intensity_en(en_lims=[1.2, 1.4])
v0 = sys.get_intensity_en(en_lims=[.4, .8])
v1 = sys.get_intensity_en(en_lims=[1., 1.2])
v2 = sys.get_intensity_en(en_lims=[1.4, 1.51])
plot.intensity_area(ll0, s=20, plt_hop=True);
plot.intensity_area(ll1, s=20, plt_hop=True);
plot.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 24 states between -0.2 and 0.2
# 21 states between 0.8 and 1.0
# 18 states between 1.2 and 1.4
# 1 states between 0.4 and 0.8
# 3 states between 1.0 and 1.2
# 5 states between 1.4 and 1.51
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
plot.intensity_area(v0, s=20, plt_hop=True);
plot.intensity_area(v1, s=20, plt_hop=True);
plot.intensity_area(v2, s=20, plt_hop=True);
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Hoftstater Butterfly

# %% [markdown]
# ### triangular flake

# %%
lat = grapheneTB()
lat.triangle_zigzag(24)
sys = grapheneEig(lat)
sys.get_butterfly(t=1, N=20)
plot = plotTB(sys)
plot.butterfly();
# Out:
# Strain limits: [-0.17777678  0.38095338]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### hexagonal flake

# %%
lat = grapheneTB()
lat.hexagon_zigzag(10)
sys = grapheneEig(lat)
sys.get_butterfly(t=1, N=20)
plot = plotTB(sys)
plot.butterfly();
# Out:
# Strain limits: [-0.2962953  0.2962973]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### circular flake

# %%
lat = grapheneTB()
lat.circle(20)
sys = grapheneEig(lat)
sys.get_butterfly(t=1, N=30)
plot = plotTB(sys)
plot.butterfly();
# Out:
# Strain limits: [-0.2962953  0.2962973]
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:1718: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
lat = grapheneTB()
lat.circle(4)
lat.plot(ms=5);

# %%
lat1 = grapheneTB()
lat1.circle(2)
lat1.plot(ms=5);

# %%
lat -= lat1
lat.plot(ms=5);

# %%
print(lat.coor)
# Out:
# [(-2.5980760000000000004, -0.5, b'b') (-2.5980760000000000004, 0.5, b'a')
#  (-1.7320510000000000003, -2.0, b'b') (-1.7320510000000000003, -1.0, b'a')
#  (-1.7320510000000000003, 1.0, b'b') (-1.7320510000000000003, 2.0, b'a')
#  (-0.86602500000000000031, -2.5, b'a')
#  (-0.86602500000000000031, -0.5, b'b') (-0.86602500000000000031, 0.5, b'a')
#  (-0.86602500000000000031, 2.5, b'b')
#  (-4.336808689942017736e-19, -2.0, b'b')
#  (-4.336808689942017736e-19, -1.0, b'a')
#  (-4.336808689942017736e-19, 1.0, b'b')
#  (-4.336808689942017736e-19, 2.0, b'a')
#  (0.86602499999999999966, -2.5, b'a') (0.86602499999999999966, -0.5, b'b')
#  (0.86602499999999999966, 0.5, b'a') (0.86602499999999999966, 2.5, b'b')
#  (1.7320509999999999999, -2.0, b'b') (1.7320509999999999999, -1.0, b'a')
#  (1.7320509999999999999, 1.0, b'b') (1.7320509999999999999, 2.0, b'a')
#  (2.5980759999999999996, -0.5, b'b') (2.5980759999999999996, 0.5, b'a')]

# %%
print(lat1.coor)
# Out:
# [(-0.86602575000000000009, -0.5, b'b') (-0.86602575000000000009, 0.5, b'a')
#  (2.4999999999992476157e-07, -1.0, b'a')
#  (2.4999999999992476157e-07, 1.0, b'b')
#  (0.86602524999999999991, -0.5, b'b') (0.86602524999999999991, 0.5, b'a')]

# %%
lat1.coor[0] in lat.coor
# Out:
# False

# %%
np.round(lat1.coor['x'][0], 5) in np.round(lat.coor['x'], 5)
# Out:
# True

# %%
np.round(lat.coor['x'], 3)
# Out:
# array([-2.598, -2.598, -1.732, -1.732, -1.732, -1.732, -0.866, -0.866,
#        -0.866, -0.866,  -0.0,  -0.0,  -0.0,  -0.0,  0.866,  0.866,  0.866,
#         0.866,  1.732,  1.732,  1.732,  1.732,  2.598,  2.598], dtype=float128)

# %%
lat = grapheneTB()
lat.square(10)
lat.plot(ms=5);

# %%
lat
