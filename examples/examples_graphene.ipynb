# %% [markdown]
# # GRAPHENE FLAKES

# %%
# tbee must be importable: `pip install -e .` from the repository root
# (recommended), or run this notebook from within examples/ and it will
# find the package via the fallback below.
import sys, os
try:
    import tbee
except ImportError:
    sys.path.insert(0, os.path.abspath('..'))

# %%
from tbee.graphene import *
from tbee.save import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Quick examples

# %% [markdown]
# ### lattice with nearest and next-nearest hoppings

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.get_lattice(n1=10, n2=10)
plt.lattice(ms=8);

# %%
sys.set_hopping([{'n':1, 't':1.}, {'n':2, 't':.5}])

# %%
sys.get_ham()
sys.get_eig()
plt.spectrum();

# %% [markdown]
# ### lattice with different hopping values

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.get_lattice(n1=6, n2=6)
plt.lattice(ms=8);

# %%
sys.print_distances(n=2)
# Out:
# 54 different distances between sites:
#
# Distances between sites:
# 1st hopping, length: 1.000
# 	with positive angles:
# 	 [ 30.  90. 150.]
# 2nd hopping, length: 1.732
# 	with positive angles:
# 	 [  0.  60. 120.]

# %%
sys.set_hopping([{'n': 1, 'ang': 90,'t':2}, 
                 {'n': 1, 'ang': 30,'t':1.5},
                 {'n': 1, 'ang': 150,'t':1}])

# %%
sys.get_coor_hop()
plt.lattice_hop(ms=10);

# %%
sys.get_ham()
sys.get_eig()
plt.spectrum();

# %% [markdown]
# ### Triangular flake with zigzag terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)
sav = save(dir_name='graphene')

lat.triangle_zigzag(16)
plt.lattice(ms=6);

# %%
sys.set_hopping([{'n':1, 't':1.}])
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', fs=15);

# %%
zero_modes = sys.get_intensity_en(lims=[-0.1, 0.1])
fig_trizz_zm = plt.intensity_area(zero_modes, s=20, 
                                  plt_hop=True, title='');
sav.fig(fig_trizz_zm, 'trizz_zm_n16')
# Out:
# 16 states between -0.1 and 0.1

# %% [markdown]
# # GRAPHENE FLAKES UNDER LINEAR TRIAXIAL STRAIN

# %% [markdown]
# ## Strained Hexagonal Flakes

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

# %%
lat.hexagon_zigzag(5)
lat.center()
betas = sys.get_beta_lims()
# Out:
# Strain limits: [-0.66666567  0.66666767]

# %% [markdown]
# ### Increasing negative strain

# %%
sys.set_hop_linear_strain(t=1, beta=1/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[0]);
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ### Increasing positive strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ## Strained Triangular Flakes

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(10)
lat.center()
betas = sys.get_beta_lims()
# Out:
# Strain limits: [-0.47058724  1.14285814]

# %% [markdown]
# ### Increasing negative strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[0])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ### Increasing positive strain

# %%
sys.set_hop_linear_strain(t=1, beta=0)
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=1/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=2/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

sys.set_hop_linear_strain(t=1, beta=3/4*betas[1])
sys.get_coor_hop()
plt.lattice_hop(ms=5, c=0.4, plt_hop=True, figsize=(3, 3));

# %% [markdown]
# ## Pseudo Landau levels in the triangular flake with zigzag terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(25)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.17021177  0.36363736]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', lims=[-2.1, 2.1], fs=15);

# %%
ll0 = sys.get_intensity_en(lims=[-0.1, 0.1])
ll1 = sys.get_intensity_en(lims=[0.8, 1.])
ll2 = sys.get_intensity_en(lims=[1., 1.4])
ll3 = sys.get_intensity_en(lims=[1.4, 1.6])
ll4 = sys.get_intensity_en(lims=[1.6, 1.8])
ll5 = sys.get_intensity_en(lims=[1.9, 2.])
ll6 = sys.get_intensity_en(lims=[2., 2.1])

plt.intensity_area(ll0, s=20, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
plt.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 25 states between -0.1 and 0.1
# 24 states between 0.8 and 1.0
# 23 states between 1.0 and 1.4
# 22 states between 1.4 and 1.6
# 21 states between 1.6 and 1.8
# 20 states between 1.9 and 2.0
# 19 states between 2.0 and 2.1

# %%
plt.intensity_area(ll3, s=20, plt_hop=True);
plt.intensity_area(ll4, s=20, plt_hop=True);
plt.intensity_area(ll5, s=20, plt_hop=True);

# %% [markdown]
# ## Pseudo Landau levels in the hexagonal flake with zigzag terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.hexagon_zigzag(10)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.2962953  0.2962973]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', fs=15, lims=[-2.1, 2.1]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.2, 0.2])
ll1 = sys.get_intensity_en(lims=[0.6, 1.])
ll2 = sys.get_intensity_en(lims=[1., 1.35])
plt.intensity_area(ll0, s=15, plt_hop=True);
plt.intensity_area(ll1, s=15, plt_hop=True);
plt.intensity_area(ll2, s=15, plt_hop=True);
# Out:
# 60 states between -0.2 and 0.2
# 29 states between 0.6 and 1.0
# 28 states between 1.0 and 1.35

# %% [markdown]
# ## Pseudo Landau levels in the squared flake

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.square(n=15)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.31373493  0.31371605]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', fs=15, lims=[-2., 2.]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.6, 0.6])
ll1 = sys.get_intensity_en(lims=[0.6, 1.])
plt.intensity_area(ll0, s=20, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
# Out:
# 59 states between -0.6 and 0.6
# 26 states between 0.6 and 1.0

# %% [markdown]
# ## Pseudo Landau levels in the circular flake

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.circle(18)
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.26666567  0.26666767]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', fs=15, lims=[-1.5, 1.5]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.3, 0.3])
ll1 = sys.get_intensity_en(lims=[0.5, 1.])
ll2 = sys.get_intensity_en(lims=[1., 1.3])
plt.intensity_area(ll0, s=15, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
plt.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 58 states between -0.3 and 0.3
# 29 states between 0.5 and 1.0
# 28 states between 1.0 and 1.3

# %% [markdown]
# ## Pseudo Landau levels in the triangular flake with armchair terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_armchair(n=14)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.20512721  0.20512921]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', fs=15, lims=[-1., 1.]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.6, 0.6])
plt.intensity_area(ll0, s=10, plt_hop=True, title='');
# Out:
# 54 states between -0.6 and 0.6

# %% [markdown]
# ## Pseudo Landau levels in the hexagonal flake with armchair terminations

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.hexagon_armchair(7)
lat.center()
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_coor_hop()
plt.lattice(ms=5);
plt.lattice_hop(ms=5);
# Out:
# Strain limits: [-0.22222122  0.22222322]

# %%
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', fs=15, lims=[-2.2, 2.2]);

# %%
ll0 = sys.get_intensity_en(lims=[-0.5, 0.5])
ll1 = sys.get_intensity_en(lims=[0.6, 0.9])
ll2 = sys.get_intensity_en(lims=[.9, 1.15])
plt.intensity_area(ll0, s=12, plt_hop=True);
plt.intensity_area(ll1, s=20, plt_hop=True);
plt.intensity_area(ll2, s=20, plt_hop=True);
# Out:
# 66 states between -0.5 and 0.5
# 32 states between 0.6 and 0.9
# 28 states between 0.9 and 1.15

# %% [markdown]
# ## Vacancy leading to localized states between pLLs

# %% [markdown]
# ### site A at the center of mass removed

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(16)
lat.center()
lat.plot(ms=2, plt_index=True, fs=8, axis=True);

# %% [markdown]
# Note: not using 'matplotlib inline' allows to zoom
# (easier to find a specific index if the lattice is large)

# %%
lat.remove_sites([140])

# %%
lat.plot(ms=6, axis=True);

# %%
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', fs=15, lims=[-2.2, 2.2]);
# Out:
# Strain limits: [-0.27586107  0.61538562]

# %%
ls0 = sys.get_intensity_en(lims=[0.6, 0.8])
ls1 = sys.get_intensity_en(lims=[1.85, 1.9])
plt.intensity_area(ls0, s=50, plt_hop=True);
plt.intensity_area(ls1, s=50, plt_hop=True);
# Out:
# 1 states between 0.6 and 0.8
# 1 states between 1.85 and 1.9

# %% [markdown]
# ### site B at the center of mass removed

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(17)
lat.center()
lat.plot(ms=2, plt_index=True, fs=8, axis=True);

# %%
lat.remove_sites([162])

# %%
lat.plot(ms=6, axis=True);

# %%
betas = sys.get_beta_lims()
sys.set_hop_linear_strain(t=1, beta=betas[1])
sys.get_ham()
sys.get_eig(eigenvec=True)
plt.spectrum(tag_pola='a', fs=15, lims=[-2.2, 2.2]);  #lims=[-2.2, 2.2]
# Out:
# Strain limits: [-0.25806352  0.57142957]

# %%
ls1 = sys.get_intensity_en(lims=[1.7, 1.8])
plt.intensity_area(ls1, s=50, plt_hop=True);
# Out:
# 1 states between 1.7 and 1.8

# %% [markdown]
# ## Hoftstater Butterfly

# %% [markdown]
# ### triangular flake

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.triangle_zigzag(20)
lat.center()
sys.get_butterfly(t=1, N=30)
# Out:
# Strain limits: [-0.21621522  0.47058924]

# %%
plt.butterfly(sys.betas, sys.butterfly, lims=[-2., 2.]);

# %% [markdown]
# ### hexagonal flake

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.hexagon_zigzag(8)
lat.center()
sys.get_butterfly(t=1, N=30)
plt.butterfly(sys.betas, sys.butterfly, lims=[-1.5, 1.5]);
# Out:
# Strain limits: [-0.38095138  0.38095338]

# %% [markdown]
# ### circular flake

# %%
lat = grapheneLat()
sys = grapheneSys(lat=lat)
plt = plot(sys=sys)

lat.circle(16)
lat.center()
sys.get_butterfly(t=1, N=30)
plt.butterfly(sys.betas, sys.butterfly, lims=[-1.5, 1.5]);
# Out:
# Strain limits: [-0.2962953  0.2962973]
